# %%
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
import keras_contrib.optimizers.lr_multiplier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-64f6590b2b8c> in <module>
# ----> 1 import keras_contrib.optimizers.lr_multiplier
#
# ModuleNotFoundError: No module named 'keras_contrib.optimizers.lr_multiplier'

# %%
names = os.listdir('/home/ferseiti/Pictures/')
names = sorted(names)
nums = len(names)
print(nums, names)
# Out:
# 9 ['Pipeline1.png', 'Webcam', 'allyne_photos', 'coupmonies.png', 'slice1404.pgm', 'ss_gephi.png', 'vini', 'webcam.jpg', 'xboxlive.png']

# %%
hr_img = mpimg.imread('/home/ferseiti/Pictures/xboxlive.png')

# %%
hr_img.shape
# Out:
# (640, 640, 4)

# %%
plt.imshow(hr_img[:,:,:3])

# %%
b = np.arange(100).reshape((10,10))

# %%
b[1::2,1::2]
# Out:
# array([[11, 13, 15, 17, 19],
#        [31, 33, 35, 37, 39],
#        [51, 53, 55, 57, 59],
#        [71, 73, 75, 77, 79],
#        [91, 93, 95, 97, 99]])
