# %%
from keras.models import Sequential
from keras.layers import Conv2D, Input, BatchNormalization
# from keras.layers.advanced_activations import LeakyReLU
from keras.callbacks import ModelCheckpoint, Callback
from keras.optimizers import SGD, Adam
from keras.utils.training_utils import multi_gpu_model
from keras.preprocessing.image import ImageDataGenerator
from keras import initializers
import prepare_data as pd
import numpy
import math
import scipy.misc as spm

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from PIL import Image

from lr_multiplier import LearningRateMultiplier

import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.2
set_session(tf.Session(config=config))
# Out:
# Using TensorFlow backend.

# %%
# see example https://github.com/keras-team/keras/issues/8649
class MyCbk(Callback):

    def __init__(self, model):
         self.model_to_save = model

    def on_epoch_end(self, epoch, logs=None):
        self.model_to_save.save('checkpoints/64-9-5-5_128-64-SRCNN_model_at_epoch_%d.h5' % epoch)

# %%
def psnr(target, ref):
    # assume RGB image
    target_data = numpy.array(target, dtype=float)
    ref_data = numpy.array(ref, dtype=float)

    diff = ref_data - target_data
    diff = diff.flatten('C')

    rmse = math.sqrt(numpy.mean(diff ** 2.))

    return 20 * math.log10(255. / rmse)

# %%
def model(optimizer='SGD', all_layers=True, processing='GPU', lr=0.0001):
    # lrelu = LeakyReLU(alpha=0.1)                                              
#     SRCNN = Sequential()                                                        
#     SRCNN.add(Conv2D(filters=128, kernel_size=(9, 9), init='glorot_uniform',  
#                      activation='relu', border_mode='valid', bias=True, input_shape=(32, 32, 1)))
#     SRCNN.add(Conv2D(filters=64, kernel_size=(3, 3), init='glorot_uniform',   
#                      activation='relu', border_mode='same', bias=True))         
#     # SRCNN.add(BatchNormalization())                                           
#     SRCNN.add(Conv2D(filters=1, kernel_size=(5, 5), init='glorot_uniform',    
#                      activation='linear', border_mode='valid', bias=True))      
#     adam = Adam(lr=0.0001)                                                     
# #     sgd = SGD(lr=0.0003)                                                        
#     SRCNN.compile(optimizer=adam, loss='mean_squared_error', metrics=['mean_squared_error'])
#     return SRCNN 

    multipliers = {'conv2d_1': 1, 'conv2d_2': 1, 'conv2d_3': 0.1}
    
    optimizer = optimizer.upper()
    processing = processing.upper()
    
    print('Using {}.'.format(optimizer))

    if optimizer == 'SGD' and all_layers:
        opt = LearningRateMultiplier(SGD, lr_multipliers=multipliers, lr=lr)
    elif optimizer == 'SGD':
        opt = SGD(lr=0.0001)
    elif all_layers:
        opt = LearningRateMultiplier(Adam, lr_multipliers=multipliers, lr=lr)
    else:
        opt = Adam(lr=lr)
    # lrelu = LeakyReLU(alpha=0.1)
    
    SRCNN = Sequential()
    SRCNN.add(Conv2D(filters=128, kernel_size=(9, 9), 
                     kernel_initializer='glorot_uniform', bias_initializer='random_uniform',
                     activation='relu', padding='valid', use_bias=True, input_shape=(64, 64, 1), name='conv2d_1'))

    SRCNN.add(Conv2D(filters=64, kernel_size=(5, 5), 
                     kernel_initializer='glorot_uniform', bias_initializer='random_uniform',
                     activation='relu', padding='same', use_bias=True, name='conv2d_2'))
    
    # SRCNN.add(BatchNormalization())
    SRCNN.add(Conv2D(filters=1, kernel_size=(5, 5),
                     kernel_initializer='glorot_uniform', bias_initializer='random_uniform',
                     activation='linear', padding='valid', use_bias=True,  name='conv2d_3'))
    SRCNN_MULTI = multi_gpu_model(SRCNN, gpus=8)
    if processing == 'GPU':    
        SRCNN_MULTI.compile(optimizer=opt, loss='mean_squared_error', metrics=['mean_squared_error'])
    else:
        SRCNN.compile(optimizer=opt, loss='mean_squared_error', metrics=['mean_squared_error'])
    return SRCNN, SRCNN_MULTI

# %%
def predict_model():
    # lrelu = LeakyReLU(alpha=0.1)
    sgd = SGD(lr=0.0001)
    
    SRCNN = Sequential()
    SRCNN.add(Conv2D(filters=128, kernel_size=(9, 9), 
                     kernel_initializer='glorot_uniform', bias_initializer='random_uniform',
                     activation='relu', padding='valid', use_bias=True, input_shape=(None, None, 1), name='conv2d_1'))
        
    SRCNN.add(Conv2D(filters=64, kernel_size=(5, 5), 
                     kernel_initializer='glorot_uniform', bias_initializer='random_uniform',
                     activation='relu', padding='same', use_bias=True, name='conv2d_2'))
        
    # SRCNN.add(BatchNormalization())
    SRCNN.add(Conv2D(filters=1, kernel_size=(5, 5),
                     kernel_initializer='glorot_uniform', bias_initializer='random_uniform',
                     activation='linear', padding='valid', use_bias=True,  name='conv2d_3'))
    adam = Adam(lr=0.0003)
    sgd_last = SGD(lr=0.00001)

    SRCNN.compile(optimizer=adam, loss='mean_squared_error', metrics=['mean_squared_error'])
    return SRCNN

# %%
def train(processing='GPU', optimizer='SGD', use_data_augmentation=False, epochs=200, lr=0.0001):
#     srcnn_model = model()
#     print(srcnn_model.summary())                                                
#     data, label = pd.read_training_data("./crop_train.h5")
#     val_data, val_label = pd.read_training_data("./test.h5")                    
                                                                                
#     checkpoint = ModelCheckpoint("SRCNN_check.h5", monitor='val_loss', verbose=1, save_best_only=True,
#                                  save_weights_only=False, mode='min')           
#     callbacks_list = [checkpoint]                                               
                                                                                
#     srcnn_model.fit(data, label, batch_size=1024,
#                     callbacks=callbacks_list, shuffle=True, nb_epoch=200, verbose=2, validation_split=0.2)

    optimizer = optimizer.upper()
    processing = processing.upper()
    
    srcnn_model, srcnn_multi_model = model(optimizer=optimizer, processing=processing, lr=lr)

    callbacks_list = []
    BS = 1024
    
    if processing == 'GPU' or use_data_augmentation:    
        print(srcnn_multi_model.summary())
        # see example https://github.com/keras-team/keras/issues/8649
        cbk = MyCbk(srcnn_model)
        
    else:
        print(srcnn_model.summary())
        checkpoint = ModelCheckpoint("64SRCNN_check.h5", monitor='val_loss', 
                                     verbose=2, 
                                     save_best_only=True,
                                     save_weights_only=False)
        callbacks_list.append(checkpoint)
        
    data, label = pd.read_training_data("./64crop_train.h5")
    val_data, val_label = pd.read_training_data("./64test.h5")

    max_value = data.max()

    data = data/max_value
    label = label/max_value

    val_data = val_data/max_value
    val_label = val_label/max_value
    
    # construct the training image generator for data augmentation
    datagen = ImageDataGenerator(rotation_range=45,
                                 zoom_range=0.15,
                                 width_shift_range=0.2,
                                 height_shift_range=0.2,
                                 horizontal_flip=True, 
                                 vertical_flip=True)

    # train the network

    if use_data_augmentation and processing == 'GPU':
        history = srcnn_multi_model.fit_generator(datagen.flow(data, label, batch_size=BS),
                                                    validation_data=(val_data, val_label),
                                                    steps_per_epoch=len(data) // BS,
                                                    epochs=epochs, 
                                                    verbose=2, 
                                                    shuffle=True,
                                                    callbacks=[cbk],
                                                    use_multiprocessing=True)
    elif processing == 'GPU':
        srcnn_multi_model.fit(data, label, batch_size=BS,
                              validation_split=0.2,
    #                       validation_data=(val_data, val_label),
                            shuffle=True, 
                            epochs=epochs, 
                            verbose=2,
                            callbacks=[cbk])
    elif use_data_augmentation:
        history = srcnn_model.fit_generator(datagen.flow(data, label, batch_size=BS),
                                          validation_data=(val_data, val_label),
                                          steps_per_epoch=len(data) // BS,
                                          epochs=epochs, 
                                          verbose=2, 
                                          shuffle=True,
                                          callbacks=[cbk])
    else:
        srcnn_model.fit(data, label, batch_size=BS,
                            validation_split=0.2,
    #                       validation_data=(val_data, val_label),
                            shuffle=True, 
                            epochs=epochs, 
                            verbose=2,
                            callbacks=callbacks_list)

    # srcnn_model.load_weights("m_model_adam.h5")

# %%
data, label = pd.read_training_data("./64crop_train.h5")
val_data, val_label = pd.read_training_data("./64test.h5")

max_value = data.max()

data = data/max_value
label = label/max_value

val_data = val_data/max_value
val_label = val_label/max_value

# %%
def predict():
#     srcnn_model = model()[0]
    srcnn_model = predict_model()
    srcnn_model.load_weights("checkpoints/64-9-5-5_128-64-SRCNN_model_at_epoch_60.h5")
    IMG_NAME = numpy.fromfile('ground_data/pick/recon/slice_256.b', dtype = 'uint8')
    INPUT_NAME = numpy.fromfile("sub_data/pick/recon/slice_256.b", dtype = 'uint8')
    OUTPUT_NAME = "pre2.png"

    dimension_img = int(IMG_NAME.shape[0]**(1/2))
    dimension_input = int(INPUT_NAME.shape[0]**(1/2))
    
    IMG_NAME = IMG_NAME.reshape((dimension_img, dimension_img))
    INPUT_NAME = INPUT_NAME.reshape((dimension_input, dimension_input))
    
    import cv2
    img = INPUT_NAME.copy()
    shape = IMG_NAME.shape
    Y_img = img.copy()
    Y_img = spm.imresize(Y_img, size=shape, interp='bicubic')
    bicubic = Y_img.copy()

    Y_img = Y_img.reshape((dimension_img, dimension_img, 1))
    
    for i in range(Y_img.shape[-1]):
        Y = numpy.zeros((1, shape[0], shape[1], 1), dtype=float)
        Y[0,:,:,0] = Y_img[:,:,i].astype(float) / 255.
        pre = srcnn_model.predict(Y, batch_size=1) * 255.
        
    pre[pre[:] > 255] = 255
    pre[pre[:] < 0] = 0
    pre = pre.astype(float)
    print(Y_img.shape, pre.shape)
    Y_img[6: -6, 6: -6, 0] = pre[0, :, :, 0].copy()
    cv2.imwrite(OUTPUT_NAME, Y_img)

    # psnr calculation:
    im1 = IMG_NAME
    im2 = bicubic
    im3 = cv2.imread(OUTPUT_NAME)[:,:,0]
    
    print(im1.shape, im2.shape, im3.shape)

    print ("bicubic:")
    print (cv2.PSNR(im1, im2))
    print ("SRCNN:")
    print (cv2.PSNR(im1, im3))
    
    import matplotlib.pyplot as plt
    print(im1.shape)
    plt.figure(figsize=[15,30])
    plt.subplot(311)
#     plt.imshow(im1[350:450,200:400])
    plt.title('Original')
    plt.imshow(im1)
    plt.subplot(312)
#     plt.imshow(im2[350:450,200:400])
    plt.title('Bicubic')    
    plt.imshow(im2)
    plt.subplot(313)
#     plt.imshow(im3[350:450,200:400])
    plt.title('SRCNN')
    plt.imshow(im3[10:-10,10:-10])
    plt.show()

# %%
train(processing='GPU', optimizer='adam', use_data_augmentation=False, epochs=1000, lr=0.0001)
# Out:
# Using ADAM.
# WARNING:tensorflow:From /home/ABTLUS/fernando.furusato/tests/jupyter/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# conv2d_1_input (InputLayer)     (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 64, 64, 1)    0           conv2d_1_input[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 64, 64, 1)    0           conv2d_1_input[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 64, 64, 1)    0           conv2d_1_input[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 64, 64, 1)    0           conv2d_1_input[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 64, 64, 1)    0           conv2d_1_input[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 64, 64, 1)    0           conv2d_1_input[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 64, 64, 1)    0           conv2d_1_input[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 64, 64, 1)    0           conv2d_1_input[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 52, 52, 1)    216961      lambda_1[0][0]
#                                                                  lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_7[0][0]
#                                                                  lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Concatenate)          (None, 52, 52, 1)    0           sequential_1[1][0]
#                                                                  sequential_1[2][0]
#                                                                  sequential_1[3][0]
#                                                                  sequential_1[4][0]
#                                                                  sequential_1[5][0]
#                                                                  sequential_1[6][0]
#                                                                  sequential_1[7][0]
#                                                                  sequential_1[8][0]
# ==================================================================================================
# Total params: 216,961
# Trainable params: 216,961
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From /home/ABTLUS/fernando.furusato/tests/jupyter/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 160563 samples, validate on 40141 samples
# Epoch 1/1000
#  - 34s - loss: 0.0212 - mean_squared_error: 0.0212 - val_loss: 5.0828e-05 - val_mean_squared_error: 5.0828e-05
# Epoch 2/1000
#  - 18s - loss: 3.4708e-04 - mean_squared_error: 3.4708e-04 - val_loss: 2.5309e-05 - val_mean_squared_error: 2.5309e-05
# Epoch 3/1000
#  - 20s - loss: 3.4137e-04 - mean_squared_error: 3.4137e-04 - val_loss: 2.5125e-05 - val_mean_squared_error: 2.5125e-05
# Epoch 4/1000
#  - 17s - loss: 3.3729e-04 - mean_squared_error: 3.3729e-04 - val_loss: 2.5063e-05 - val_mean_squared_error: 2.5063e-05
# Epoch 5/1000
#  - 18s - loss: 3.3331e-04 - mean_squared_error: 3.3331e-04 - val_loss: 2.5031e-05 - val_mean_squared_error: 2.5031e-05
# Epoch 6/1000
#  - 18s - loss: 3.2985e-04 - mean_squared_error: 3.2985e-04 - val_loss: 2.5059e-05 - val_mean_squared_error: 2.5059e-05
# Epoch 7/1000
#  - 17s - loss: 3.2721e-04 - mean_squared_error: 3.2721e-04 - val_loss: 2.5130e-05 - val_mean_squared_error: 2.5130e-05
# Epoch 8/1000
#  - 17s - loss: 3.2527e-04 - mean_squared_error: 3.2527e-04 - val_loss: 2.5262e-05 - val_mean_squared_error: 2.5262e-05
# Epoch 9/1000
#  - 17s - loss: 3.2385e-04 - mean_squared_error: 3.2385e-04 - val_loss: 2.5351e-05 - val_mean_squared_error: 2.5351e-05
# Epoch 10/1000
#  - 18s - loss: 3.2277e-04 - mean_squared_error: 3.2277e-04 - val_loss: 2.5320e-05 - val_mean_squared_error: 2.5320e-05
# Epoch 11/1000
#  - 18s - loss: 3.2190e-04 - mean_squared_error: 3.2190e-04 - val_loss: 2.5423e-05 - val_mean_squared_error: 2.5423e-05
# Epoch 12/1000
#  - 18s - loss: 3.2117e-04 - mean_squared_error: 3.2117e-04 - val_loss: 2.5404e-05 - val_mean_squared_error: 2.5404e-05
# Epoch 13/1000
#  - 18s - loss: 3.2056e-04 - mean_squared_error: 3.2056e-04 - val_loss: 2.5451e-05 - val_mean_squared_error: 2.5451e-05
# Epoch 14/1000
#  - 17s - loss: 3.2004e-04 - mean_squared_error: 3.2004e-04 - val_loss: 2.5486e-05 - val_mean_squared_error: 2.5486e-05
# Epoch 15/1000
#  - 18s - loss: 3.1961e-04 - mean_squared_error: 3.1961e-04 - val_loss: 2.5476e-05 - val_mean_squared_error: 2.5476e-05
# Epoch 16/1000
#  - 18s - loss: 3.1925e-04 - mean_squared_error: 3.1925e-04 - val_loss: 2.5475e-05 - val_mean_squared_error: 2.5475e-05
# Epoch 17/1000
#  - 18s - loss: 3.1778e-04 - mean_squared_error: 3.1778e-04 - val_loss: 2.5541e-05 - val_mean_squared_error: 2.5541e-05
# Epoch 25/1000
#  - 18s - loss: 3.1768e-04 - mean_squared_error: 3.1768e-04 - val_loss: 2.5669e-05 - val_mean_squared_error: 2.5669e-05
# Epoch 26/1000
#  - 18s - loss: 3.1765e-04 - mean_squared_error: 3.1765e-04 - val_loss: 2.5538e-05 - val_mean_squared_error: 2.5538e-05
# Epoch 27/1000
#  - 17s - loss: 3.1757e-04 - mean_squared_error: 3.1757e-04 - val_loss: 2.5541e-05 - val_mean_squared_error: 2.5541e-05
# Epoch 28/1000
#  - 18s - loss: 3.1759e-04 - mean_squared_error: 3.1759e-04 - val_loss: 2.5567e-05 - val_mean_squared_error: 2.5567e-05
# Epoch 29/1000
#  - 18s - loss: 3.1754e-04 - mean_squared_error: 3.1754e-04 - val_loss: 2.5534e-05 - val_mean_squared_error: 2.5534e-05
# Epoch 30/1000
#  - 19s - loss: 3.1770e-04 - mean_squared_error: 3.1770e-04 - val_loss: 2.5878e-05 - val_mean_squared_error: 2.5878e-05
# Epoch 31/1000
#  - 17s - loss: 3.1768e-04 - mean_squared_error: 3.1768e-04 - val_loss: 2.6630e-05 - val_mean_squared_error: 2.6630e-05
# Epoch 32/1000
#  - 20s - loss: 3.1775e-04 - mean_squared_error: 3.1775e-04 - val_loss: 2.5546e-05 - val_mean_squared_error: 2.5546e-05
# Epoch 33/1000
#  - 18s - loss: 3.1820e-04 - mean_squared_error: 3.1820e-04 - val_loss: 2.5581e-05 - val_mean_squared_error: 2.5581e-05
# Epoch 34/1000
#  - 18s - loss: 3.1830e-04 - mean_squared_error: 3.1830e-04 - val_loss: 2.5545e-05 - val_mean_squared_error: 2.5545e-05
# Epoch 35/1000
#  - 18s - loss: 3.1905e-04 - mean_squared_error: 3.1905e-04 - val_loss: 2.5549e-05 - val_mean_squared_error: 2.5549e-05
# Epoch 36/1000
#  - 18s - loss: 3.1775e-04 - mean_squared_error: 3.1775e-04 - val_loss: 2.8409e-05 - val_mean_squared_error: 2.8409e-05
# Epoch 37/1000
#  - 18s - loss: 3.1866e-04 - mean_squared_error: 3.1866e-04 - val_loss: 2.5562e-05 - val_mean_squared_error: 2.5562e-05
# Epoch 38/1000
#  - 21s - loss: 3.1902e-04 - mean_squared_error: 3.1902e-04 - val_loss: 2.6312e-05 - val_mean_squared_error: 2.6312e-05
# Epoch 39/1000
#  - 20s - loss: 3.1877e-04 - mean_squared_error: 3.1877e-04 - val_loss: 2.5761e-05 - val_mean_squared_error: 2.5761e-05
# Epoch 40/1000
#  - 22s - loss: 3.1923e-04 - mean_squared_error: 3.1923e-04 - val_loss: 2.7990e-05 - val_mean_squared_error: 2.7990e-05
# Epoch 41/1000
#  - 19s - loss: 3.1906e-04 - mean_squared_error: 3.1906e-04 - val_loss: 2.6258e-05 - val_mean_squared_error: 2.6258e-05
# Epoch 42/1000
#  - 21s - loss: 3.1930e-04 - mean_squared_error: 3.1930e-04 - val_loss: 2.6060e-05 - val_mean_squared_error: 2.6060e-05
# Epoch 43/1000
#  - 19s - loss: 3.1929e-04 - mean_squared_error: 3.1929e-04 - val_loss: 2.5561e-05 - val_mean_squared_error: 2.5561e-05
# Epoch 44/1000
#  - 20s - loss: 3.1840e-04 - mean_squared_error: 3.1840e-04 - val_loss: 2.6079e-05 - val_mean_squared_error: 2.6079e-05
# Epoch 45/1000
#  - 19s - loss: 3.1939e-04 - mean_squared_error: 3.1939e-04 - val_loss: 2.6812e-05 - val_mean_squared_error: 2.6812e-05
# Epoch 46/1000
#  - 22s - loss: 3.2006e-04 - mean_squared_error: 3.2006e-04 - val_loss: 2.5565e-05 - val_mean_squared_error: 2.5565e-05
# Epoch 47/1000
#  - 18s - loss: 3.1873e-04 - mean_squared_error: 3.1873e-04 - val_loss: 2.5716e-05 - val_mean_squared_error: 2.5716e-05
# Epoch 48/1000
#  - 21s - loss: 3.1811e-04 - mean_squared_error: 3.1811e-04 - val_loss: 2.5715e-05 - val_mean_squared_error: 2.5715e-05
# Epoch 49/1000
#  - 21s - loss: 3.1999e-04 - mean_squared_error: 3.1999e-04 - val_loss: 2.5930e-05 - val_mean_squared_error: 2.5930e-05
# Epoch 50/1000
#  - 19s - loss: 3.2024e-04 - mean_squared_error: 3.2024e-04 - val_loss: 3.4045e-05 - val_mean_squared_error: 3.4045e-05
# Epoch 51/1000
#  - 21s - loss: 3.1730e-04 - mean_squared_error: 3.1730e-04 - val_loss: 2.6080e-05 - val_mean_squared_error: 2.6080e-05
# Epoch 52/1000
#  - 19s - loss: 3.1970e-04 - mean_squared_error: 3.1970e-04 - val_loss: 2.5583e-05 - val_mean_squared_error: 2.5583e-05
# Epoch 53/1000
#  - 21s - loss: 3.1885e-04 - mean_squared_error: 3.1885e-04 - val_loss: 2.6730e-05 - val_mean_squared_error: 2.6730e-05
# Epoch 54/1000
#  - 18s - loss: 3.2054e-04 - mean_squared_error: 3.2054e-04 - val_loss: 2.5613e-05 - val_mean_squared_error: 2.5613e-05
# Epoch 55/1000
#  - 21s - loss: 3.1719e-04 - mean_squared_error: 3.1719e-04 - val_loss: 2.7556e-05 - val_mean_squared_error: 2.7556e-05
# Epoch 56/1000
#  - 18s - loss: 3.1852e-04 - mean_squared_error: 3.1852e-04 - val_loss: 2.8517e-05 - val_mean_squared_error: 2.8517e-05
# Epoch 57/1000
#  - 19s - loss: 3.1952e-04 - mean_squared_error: 3.1952e-04 - val_loss: 2.5810e-05 - val_mean_squared_error: 2.5810e-05
# Epoch 58/1000
#  - 21s - loss: 3.1864e-04 - mean_squared_error: 3.1864e-04 - val_loss: 2.5594e-05 - val_mean_squared_error: 2.5594e-05
# Epoch 59/1000
#  - 19s - loss: 3.1863e-04 - mean_squared_error: 3.1863e-04 - val_loss: 2.5721e-05 - val_mean_squared_error: 2.5721e-05
# Epoch 60/1000
#  - 21s - loss: 3.1835e-04 - mean_squared_error: 3.1835e-04 - val_loss: 2.5665e-05 - val_mean_squared_error: 2.5665e-05
# Epoch 61/1000
#  - 19s - loss: 3.1850e-04 - mean_squared_error: 3.1850e-04 - val_loss: 2.6175e-05 - val_mean_squared_error: 2.6175e-05
# Epoch 62/1000
#  - 18s - loss: 3.1925e-04 - mean_squared_error: 3.1925e-04 - val_loss: 2.5630e-05 - val_mean_squared_error: 2.5630e-05
# Epoch 63/1000
#  - 20s - loss: 3.1820e-04 - mean_squared_error: 3.1820e-04 - val_loss: 2.5597e-05 - val_mean_squared_error: 2.5597e-05
# Epoch 64/1000
#  - 21s - loss: 3.1895e-04 - mean_squared_error: 3.1895e-04 - val_loss: 2.6530e-05 - val_mean_squared_error: 2.6530e-05
# Epoch 65/1000
#  - 18s - loss: 3.1920e-04 - mean_squared_error: 3.1920e-04 - val_loss: 2.5588e-05 - val_mean_squared_error: 2.5588e-05
# Epoch 66/1000
#  - 21s - loss: 3.1774e-04 - mean_squared_error: 3.1774e-04 - val_loss: 3.2103e-05 - val_mean_squared_error: 3.2103e-05
# Epoch 67/1000
#  - 18s - loss: 3.1835e-04 - mean_squared_error: 3.1835e-04 - val_loss: 2.7449e-05 - val_mean_squared_error: 2.7449e-05
# Epoch 68/1000
#  - 22s - loss: 3.1856e-04 - mean_squared_error: 3.1856e-04 - val_loss: 2.6300e-05 - val_mean_squared_error: 2.6300e-05
# Epoch 69/1000
#  - 18s - loss: 3.1822e-04 - mean_squared_error: 3.1822e-04 - val_loss: 2.9746e-05 - val_mean_squared_error: 2.9746e-05
# Epoch 70/1000
#  - 22s - loss: 3.1908e-04 - mean_squared_error: 3.1908e-04 - val_loss: 2.6213e-05 - val_mean_squared_error: 2.6213e-05
# Epoch 71/1000
#  - 19s - loss: 3.1783e-04 - mean_squared_error: 3.1783e-04 - val_loss: 2.7642e-05 - val_mean_squared_error: 2.7642e-05
# Epoch 72/1000
#  - 19s - loss: 3.1784e-04 - mean_squared_error: 3.1784e-04 - val_loss: 2.5744e-05 - val_mean_squared_error: 2.5744e-05
# Epoch 73/1000
#  - 21s - loss: 3.1808e-04 - mean_squared_error: 3.1808e-04 - val_loss: 2.7106e-05 - val_mean_squared_error: 2.7106e-05
# Epoch 74/1000
#  - 19s - loss: 3.1916e-04 - mean_squared_error: 3.1916e-04 - val_loss: 2.5584e-05 - val_mean_squared_error: 2.5584e-05
# Epoch 75/1000
#  - 17s - loss: 3.1734e-04 - mean_squared_error: 3.1734e-04 - val_loss: 2.5581e-05 - val_mean_squared_error: 2.5581e-05
# Epoch 76/1000
#  - 19s - loss: 3.1909e-04 - mean_squared_error: 3.1909e-04 - val_loss: 2.5706e-05 - val_mean_squared_error: 2.5706e-05
# Epoch 77/1000
#  - 17s - loss: 3.1720e-04 - mean_squared_error: 3.1720e-04 - val_loss: 2.6476e-05 - val_mean_squared_error: 2.6476e-05
# Epoch 78/1000
#  - 19s - loss: 3.1900e-04 - mean_squared_error: 3.1900e-04 - val_loss: 2.5599e-05 - val_mean_squared_error: 2.5599e-05
# Epoch 79/1000
#  - 17s - loss: 3.1747e-04 - mean_squared_error: 3.1747e-04 - val_loss: 2.5582e-05 - val_mean_squared_error: 2.5582e-05
# Epoch 80/1000
#  - 18s - loss: 3.1839e-04 - mean_squared_error: 3.1839e-04 - val_loss: 2.8859e-05 - val_mean_squared_error: 2.8859e-05
# Epoch 81/1000
#  - 16s - loss: 3.1766e-04 - mean_squared_error: 3.1766e-04 - val_loss: 4.0009e-05 - val_mean_squared_error: 4.0009e-05
# Epoch 82/1000
#  - 17s - loss: 3.1817e-04 - mean_squared_error: 3.1817e-04 - val_loss: 2.7289e-05 - val_mean_squared_error: 2.7289e-05
# Epoch 83/1000
#  - 17s - loss: 3.1839e-04 - mean_squared_error: 3.1839e-04 - val_loss: 2.5665e-05 - val_mean_squared_error: 2.5665e-05
# Epoch 84/1000
#  - 18s - loss: 3.1750e-04 - mean_squared_error: 3.1750e-04 - val_loss: 2.6047e-05 - val_mean_squared_error: 2.6047e-05
# Epoch 85/1000
#  - 17s - loss: 3.1863e-04 - mean_squared_error: 3.1863e-04 - val_loss: 2.8176e-05 - val_mean_squared_error: 2.8176e-05
# Epoch 86/1000
#  - 18s - loss: 3.1731e-04 - mean_squared_error: 3.1731e-04 - val_loss: 2.5791e-05 - val_mean_squared_error: 2.5791e-05
# Epoch 87/1000
#  - 16s - loss: 3.1784e-04 - mean_squared_error: 3.1784e-04 - val_loss: 2.6442e-05 - val_mean_squared_error: 2.6442e-05
# Epoch 88/1000
#  - 18s - loss: 3.1787e-04 - mean_squared_error: 3.1787e-04 - val_loss: 3.6877e-05 - val_mean_squared_error: 3.6877e-05
# Epoch 89/1000
#  - 17s - loss: 3.1837e-04 - mean_squared_error: 3.1837e-04 - val_loss: 2.5880e-05 - val_mean_squared_error: 2.5880e-05
# Epoch 90/1000
#  - 17s - loss: 3.1787e-04 - mean_squared_error: 3.1787e-04 - val_loss: 2.5652e-05 - val_mean_squared_error: 2.5652e-05
# Epoch 91/1000
#  - 17s - loss: 3.1749e-04 - mean_squared_error: 3.1749e-04 - val_loss: 2.5670e-05 - val_mean_squared_error: 2.5670e-05
# Epoch 92/1000
#  - 17s - loss: 3.1767e-04 - mean_squared_error: 3.1767e-04 - val_loss: 3.0577e-05 - val_mean_squared_error: 3.0577e-05
# Epoch 93/1000
#  - 16s - loss: 3.1801e-04 - mean_squared_error: 3.1801e-04 - val_loss: 2.5586e-05 - val_mean_squared_error: 2.5586e-05
# Epoch 94/1000
#  - 18s - loss: 3.1770e-04 - mean_squared_error: 3.1770e-04 - val_loss: 2.6038e-05 - val_mean_squared_error: 2.6038e-05
# Epoch 95/1000
#  - 16s - loss: 3.1777e-04 - mean_squared_error: 3.1777e-04 - val_loss: 2.5585e-05 - val_mean_squared_error: 2.5585e-05
# Epoch 96/1000
#  - 18s - loss: 3.1782e-04 - mean_squared_error: 3.1782e-04 - val_loss: 2.7364e-05 - val_mean_squared_error: 2.7364e-05
# Epoch 97/1000
#  - 16s - loss: 3.1802e-04 - mean_squared_error: 3.1802e-04 - val_loss: 2.6603e-05 - val_mean_squared_error: 2.6603e-05
# Epoch 98/1000
#  - 20s - loss: 3.1738e-04 - mean_squared_error: 3.1738e-04 - val_loss: 2.5885e-05 - val_mean_squared_error: 2.5885e-05
# Epoch 99/1000
#  - 17s - loss: 3.1808e-04 - mean_squared_error: 3.1808e-04 - val_loss: 2.5675e-05 - val_mean_squared_error: 2.5675e-05
# Epoch 100/1000
#  - 20s - loss: 3.1703e-04 - mean_squared_error: 3.1703e-04 - val_loss: 2.5602e-05 - val_mean_squared_error: 2.5602e-05
# Epoch 101/1000
#  - 18s - loss: 3.1788e-04 - mean_squared_error: 3.1788e-04 - val_loss: 2.9637e-05 - val_mean_squared_error: 2.9637e-05
# Epoch 102/1000
#  - 20s - loss: 3.1772e-04 - mean_squared_error: 3.1772e-04 - val_loss: 2.5665e-05 - val_mean_squared_error: 2.5665e-05
# Epoch 103/1000
#  - 17s - loss: 3.1748e-04 - mean_squared_error: 3.1748e-04 - val_loss: 2.5589e-05 - val_mean_squared_error: 2.5589e-05
# Epoch 104/1000
#  - 17s - loss: 3.1814e-04 - mean_squared_error: 3.1814e-04 - val_loss: 3.2604e-05 - val_mean_squared_error: 3.2604e-05
# Epoch 105/1000
#  - 20s - loss: 3.1720e-04 - mean_squared_error: 3.1720e-04 - val_loss: 2.5699e-05 - val_mean_squared_error: 2.5699e-05
# Epoch 106/1000
#  - 21s - loss: 3.1735e-04 - mean_squared_error: 3.1735e-04 - val_loss: 2.6551e-05 - val_mean_squared_error: 2.6551e-05
# Epoch 107/1000
#  - 17s - loss: 3.1773e-04 - mean_squared_error: 3.1773e-04 - val_loss: 2.5751e-05 - val_mean_squared_error: 2.5751e-05
# Epoch 108/1000
#  - 19s - loss: 3.1742e-04 - mean_squared_error: 3.1742e-04 - val_loss: 2.5597e-05 - val_mean_squared_error: 2.5597e-05
# Epoch 109/1000
#  - 18s - loss: 3.1787e-04 - mean_squared_error: 3.1787e-04 - val_loss: 2.7610e-05 - val_mean_squared_error: 2.7610e-05
# Epoch 110/1000
#  - 19s - loss: 3.1733e-04 - mean_squared_error: 3.1733e-04 - val_loss: 3.1732e-05 - val_mean_squared_error: 3.1732e-05
# Epoch 111/1000
#  - 17s - loss: 3.1751e-04 - mean_squared_error: 3.1751e-04 - val_loss: 2.5599e-05 - val_mean_squared_error: 2.5599e-05
# Epoch 112/1000
#  - 19s - loss: 3.1731e-04 - mean_squared_error: 3.1731e-04 - val_loss: 2.6443e-05 - val_mean_squared_error: 2.6443e-05
# Epoch 113/1000
#  - 21s - loss: 3.1780e-04 - mean_squared_error: 3.1780e-04 - val_loss: 2.5588e-05 - val_mean_squared_error: 2.5588e-05
# Epoch 114/1000
#  - 17s - loss: 3.1741e-04 - mean_squared_error: 3.1741e-04 - val_loss: 2.9150e-05 - val_mean_squared_error: 2.9150e-05
# Epoch 115/1000
#  - 21s - loss: 3.1726e-04 - mean_squared_error: 3.1726e-04 - val_loss: 3.5190e-05 - val_mean_squared_error: 3.5190e-05
# Epoch 116/1000
#  - 17s - loss: 3.1729e-04 - mean_squared_error: 3.1729e-04 - val_loss: 2.5621e-05 - val_mean_squared_error: 2.5621e-05
# Epoch 117/1000
#  - 19s - loss: 3.1742e-04 - mean_squared_error: 3.1742e-04 - val_loss: 2.5850e-05 - val_mean_squared_error: 2.5850e-05
# Epoch 118/1000
#  - 20s - loss: 3.1760e-04 - mean_squared_error: 3.1760e-04 - val_loss: 2.5735e-05 - val_mean_squared_error: 2.5735e-05
# Epoch 119/1000
#  - 17s - loss: 3.1735e-04 - mean_squared_error: 3.1735e-04 - val_loss: 2.9339e-05 - val_mean_squared_error: 2.9339e-05
# Epoch 120/1000
#  - 19s - loss: 3.1724e-04 - mean_squared_error: 3.1724e-04 - val_loss: 3.2333e-05 - val_mean_squared_error: 3.2333e-05
# Epoch 121/1000
#  - 17s - loss: 3.1732e-04 - mean_squared_error: 3.1732e-04 - val_loss: 2.6240e-05 - val_mean_squared_error: 2.6240e-05
# Epoch 122/1000
#  - 20s - loss: 3.1788e-04 - mean_squared_error: 3.1788e-04 - val_loss: 2.5620e-05 - val_mean_squared_error: 2.5620e-05
# Epoch 123/1000
#  - 17s - loss: 3.1738e-04 - mean_squared_error: 3.1738e-04 - val_loss: 2.5619e-05 - val_mean_squared_error: 2.5619e-05
# Epoch 124/1000
#  - 20s - loss: 3.1713e-04 - mean_squared_error: 3.1713e-04 - val_loss: 2.5594e-05 - val_mean_squared_error: 2.5594e-05
# Epoch 125/1000
#  - 18s - loss: 3.1743e-04 - mean_squared_error: 3.1743e-04 - val_loss: 2.5620e-05 - val_mean_squared_error: 2.5620e-05
# Epoch 126/1000
#  - 20s - loss: 3.1711e-04 - mean_squared_error: 3.1711e-04 - val_loss: 2.5635e-05 - val_mean_squared_error: 2.5635e-05
# Epoch 127/1000
#  - 18s - loss: 3.1751e-04 - mean_squared_error: 3.1751e-04 - val_loss: 2.5679e-05 - val_mean_squared_error: 2.5679e-05
# Epoch 128/1000
#  - 19s - loss: 3.1725e-04 - mean_squared_error: 3.1725e-04 - val_loss: 2.6198e-05 - val_mean_squared_error: 2.6198e-05
# Epoch 129/1000
#  - 17s - loss: 3.1723e-04 - mean_squared_error: 3.1723e-04 - val_loss: 2.7291e-05 - val_mean_squared_error: 2.7291e-05
# Epoch 130/1000
#  - 19s - loss: 3.1727e-04 - mean_squared_error: 3.1727e-04 - val_loss: 2.5731e-05 - val_mean_squared_error: 2.5731e-05
# Epoch 131/1000
#  - 17s - loss: 3.1754e-04 - mean_squared_error: 3.1754e-04 - val_loss: 2.7692e-05 - val_mean_squared_error: 2.7692e-05
# Epoch 132/1000
#  - 20s - loss: 3.1722e-04 - mean_squared_error: 3.1722e-04 - val_loss: 2.5603e-05 - val_mean_squared_error: 2.5603e-05
# Epoch 133/1000
#  - 17s - loss: 3.1726e-04 - mean_squared_error: 3.1726e-04 - val_loss: 2.6321e-05 - val_mean_squared_error: 2.6321e-05
# Epoch 134/1000
#  - 19s - loss: 3.1728e-04 - mean_squared_error: 3.1728e-04 - val_loss: 2.5816e-05 - val_mean_squared_error: 2.5816e-05
# Epoch 135/1000
#  - 17s - loss: 3.1779e-04 - mean_squared_error: 3.1779e-04 - val_loss: 2.6752e-05 - val_mean_squared_error: 2.6752e-05
# Epoch 136/1000
#  - 17s - loss: 3.1678e-04 - mean_squared_error: 3.1678e-04 - val_loss: 2.5796e-05 - val_mean_squared_error: 2.5796e-05
# Epoch 137/1000
#  - 19s - loss: 3.1738e-04 - mean_squared_error: 3.1738e-04 - val_loss: 2.5949e-05 - val_mean_squared_error: 2.5949e-05
# Epoch 138/1000
#  - 17s - loss: 3.1732e-04 - mean_squared_error: 3.1732e-04 - val_loss: 2.6339e-05 - val_mean_squared_error: 2.6339e-05
# Epoch 139/1000
#  - 20s - loss: 3.1720e-04 - mean_squared_error: 3.1720e-04 - val_loss: 2.5872e-05 - val_mean_squared_error: 2.5872e-05
# Epoch 140/1000
#  - 17s - loss: 3.1756e-04 - mean_squared_error: 3.1756e-04 - val_loss: 2.5944e-05 - val_mean_squared_error: 2.5944e-05
# Epoch 141/1000
#  - 20s - loss: 3.1693e-04 - mean_squared_error: 3.1693e-04 - val_loss: 2.6410e-05 - val_mean_squared_error: 2.6410e-05
# Epoch 142/1000
#  - 17s - loss: 3.1754e-04 - mean_squared_error: 3.1754e-04 - val_loss: 2.6402e-05 - val_mean_squared_error: 2.6402e-05
# Epoch 143/1000
#  - 20s - loss: 3.1666e-04 - mean_squared_error: 3.1666e-04 - val_loss: 3.1002e-05 - val_mean_squared_error: 3.1002e-05
# Epoch 144/1000
#  - 18s - loss: 3.1743e-04 - mean_squared_error: 3.1743e-04 - val_loss: 2.8159e-05 - val_mean_squared_error: 2.8159e-05
# Epoch 145/1000
#  - 19s - loss: 3.1679e-04 - mean_squared_error: 3.1679e-04 - val_loss: 2.5619e-05 - val_mean_squared_error: 2.5619e-05
# Epoch 146/1000
#  - 17s - loss: 3.1753e-04 - mean_squared_error: 3.1753e-04 - val_loss: 2.5550e-05 - val_mean_squared_error: 2.5550e-05
# Epoch 147/1000
#  - 19s - loss: 3.1668e-04 - mean_squared_error: 3.1668e-04 - val_loss: 2.5588e-05 - val_mean_squared_error: 2.5588e-05
# Epoch 148/1000
#  - 18s - loss: 3.1754e-04 - mean_squared_error: 3.1754e-04 - val_loss: 2.6444e-05 - val_mean_squared_error: 2.6444e-05
# Epoch 149/1000
#  - 20s - loss: 3.1618e-04 - mean_squared_error: 3.1618e-04 - val_loss: 2.6042e-05 - val_mean_squared_error: 2.6042e-05
# Epoch 150/1000
#  - 17s - loss: 3.1708e-04 - mean_squared_error: 3.1708e-04 - val_loss: 2.5914e-05 - val_mean_squared_error: 2.5914e-05
# Epoch 151/1000
#  - 20s - loss: 3.1661e-04 - mean_squared_error: 3.1661e-04 - val_loss: 2.9440e-05 - val_mean_squared_error: 2.9440e-05
# Epoch 152/1000
#  - 17s - loss: 3.1722e-04 - mean_squared_error: 3.1722e-04 - val_loss: 2.6899e-05 - val_mean_squared_error: 2.6899e-05
# Epoch 153/1000
#  - 20s - loss: 3.1679e-04 - mean_squared_error: 3.1679e-04 - val_loss: 2.5471e-05 - val_mean_squared_error: 2.5471e-05
# Epoch 154/1000
#  - 17s - loss: 3.1646e-04 - mean_squared_error: 3.1646e-04 - val_loss: 2.7713e-05 - val_mean_squared_error: 2.7713e-05
# Epoch 155/1000
#  - 20s - loss: 3.1668e-04 - mean_squared_error: 3.1668e-04 - val_loss: 2.5522e-05 - val_mean_squared_error: 2.5522e-05
# Epoch 156/1000
#  - 17s - loss: 3.1657e-04 - mean_squared_error: 3.1657e-04 - val_loss: 2.7173e-05 - val_mean_squared_error: 2.7173e-05
# Epoch 157/1000
#  - 20s - loss: 3.1639e-04 - mean_squared_error: 3.1639e-04 - val_loss: 2.5768e-05 - val_mean_squared_error: 2.5768e-05
# Epoch 158/1000
#  - 17s - loss: 3.1664e-04 - mean_squared_error: 3.1664e-04 - val_loss: 2.6223e-05 - val_mean_squared_error: 2.6223e-05
# Epoch 159/1000
#  - 20s - loss: 3.1644e-04 - mean_squared_error: 3.1644e-04 - val_loss: 2.7227e-05 - val_mean_squared_error: 2.7227e-05
# Epoch 160/1000
#  - 17s - loss: 3.1657e-04 - mean_squared_error: 3.1657e-04 - val_loss: 2.5470e-05 - val_mean_squared_error: 2.5470e-05
# Epoch 161/1000
#  - 20s - loss: 3.1627e-04 - mean_squared_error: 3.1627e-04 - val_loss: 4.2186e-05 - val_mean_squared_error: 4.2186e-05
# Epoch 162/1000
#  - 17s - loss: 3.1806e-04 - mean_squared_error: 3.1806e-04 - val_loss: 2.5422e-05 - val_mean_squared_error: 2.5422e-05
# Epoch 163/1000
#  - 20s - loss: 3.1532e-04 - mean_squared_error: 3.1532e-04 - val_loss: 2.5625e-05 - val_mean_squared_error: 2.5625e-05
# Epoch 164/1000
#  - 17s - loss: 3.1635e-04 - mean_squared_error: 3.1635e-04 - val_loss: 2.7113e-05 - val_mean_squared_error: 2.7113e-05
# Epoch 165/1000
#  - 19s - loss: 3.1580e-04 - mean_squared_error: 3.1580e-04 - val_loss: 2.6819e-05 - val_mean_squared_error: 2.6819e-05
# Epoch 166/1000
#  - 17s - loss: 3.1606e-04 - mean_squared_error: 3.1606e-04 - val_loss: 2.5874e-05 - val_mean_squared_error: 2.5874e-05
# Epoch 167/1000
#  - 20s - loss: 3.1591e-04 - mean_squared_error: 3.1591e-04 - val_loss: 2.5519e-05 - val_mean_squared_error: 2.5519e-05
# Epoch 168/1000
#  - 17s - loss: 3.1614e-04 - mean_squared_error: 3.1614e-04 - val_loss: 2.7263e-05 - val_mean_squared_error: 2.7263e-05
# Epoch 169/1000
#  - 21s - loss: 3.1584e-04 - mean_squared_error: 3.1584e-04 - val_loss: 2.7634e-05 - val_mean_squared_error: 2.7634e-05
# Epoch 170/1000
#  - 17s - loss: 3.1597e-04 - mean_squared_error: 3.1597e-04 - val_loss: 2.5418e-05 - val_mean_squared_error: 2.5418e-05
# Epoch 171/1000
#  - 20s - loss: 3.1584e-04 - mean_squared_error: 3.1584e-04 - val_loss: 2.9030e-05 - val_mean_squared_error: 2.9030e-05
# Epoch 172/1000
#  - 17s - loss: 3.1567e-04 - mean_squared_error: 3.1567e-04 - val_loss: 2.5425e-05 - val_mean_squared_error: 2.5425e-05
# Epoch 173/1000
#  - 20s - loss: 3.1598e-04 - mean_squared_error: 3.1598e-04 - val_loss: 2.7390e-05 - val_mean_squared_error: 2.7390e-05
# Epoch 174/1000
#  - 18s - loss: 3.1583e-04 - mean_squared_error: 3.1583e-04 - val_loss: 2.9074e-05 - val_mean_squared_error: 2.9074e-05
# Epoch 175/1000
#  - 20s - loss: 3.1554e-04 - mean_squared_error: 3.1554e-04 - val_loss: 2.7022e-05 - val_mean_squared_error: 2.7022e-05
# Epoch 176/1000
#  - 17s - loss: 3.1587e-04 - mean_squared_error: 3.1587e-04 - val_loss: 2.5739e-05 - val_mean_squared_error: 2.5739e-05
# Epoch 177/1000
#  - 18s - loss: 3.1558e-04 - mean_squared_error: 3.1558e-04 - val_loss: 2.7687e-05 - val_mean_squared_error: 2.7687e-05
# Epoch 178/1000
#  - 18s - loss: 3.1543e-04 - mean_squared_error: 3.1543e-04 - val_loss: 2.5260e-05 - val_mean_squared_error: 2.5260e-05
# Epoch 179/1000
#  - 18s - loss: 3.1557e-04 - mean_squared_error: 3.1557e-04 - val_loss: 2.5759e-05 - val_mean_squared_error: 2.5759e-05
# Epoch 180/1000
#  - 18s - loss: 3.1573e-04 - mean_squared_error: 3.1573e-04 - val_loss: 3.2024e-05 - val_mean_squared_error: 3.2024e-05
# Epoch 181/1000
#  - 19s - loss: 3.1576e-04 - mean_squared_error: 3.1576e-04 - val_loss: 2.6033e-05 - val_mean_squared_error: 2.6033e-05
# Epoch 182/1000
#  - 18s - loss: 3.1515e-04 - mean_squared_error: 3.1515e-04 - val_loss: 2.6980e-05 - val_mean_squared_error: 2.6980e-05
# Epoch 183/1000
#  - 16s - loss: 3.1546e-04 - mean_squared_error: 3.1546e-04 - val_loss: 2.6905e-05 - val_mean_squared_error: 2.6905e-05
# Epoch 184/1000
#  - 19s - loss: 3.1527e-04 - mean_squared_error: 3.1527e-04 - val_loss: 2.5540e-05 - val_mean_squared_error: 2.5540e-05
# Epoch 185/1000
#  - 18s - loss: 3.1549e-04 - mean_squared_error: 3.1549e-04 - val_loss: 2.5246e-05 - val_mean_squared_error: 2.5246e-05
# Epoch 186/1000
#  - 17s - loss: 3.1518e-04 - mean_squared_error: 3.1518e-04 - val_loss: 2.8292e-05 - val_mean_squared_error: 2.8292e-05
# Epoch 187/1000
#  - 17s - loss: 3.1549e-04 - mean_squared_error: 3.1549e-04 - val_loss: 2.5228e-05 - val_mean_squared_error: 2.5228e-05
# Epoch 188/1000
#  - 18s - loss: 3.1532e-04 - mean_squared_error: 3.1532e-04 - val_loss: 2.8465e-05 - val_mean_squared_error: 2.8465e-05
# Epoch 189/1000
#  - 17s - loss: 3.1523e-04 - mean_squared_error: 3.1523e-04 - val_loss: 2.5202e-05 - val_mean_squared_error: 2.5202e-05
# Epoch 190/1000
#  - 18s - loss: 3.1518e-04 - mean_squared_error: 3.1518e-04 - val_loss: 2.9625e-05 - val_mean_squared_error: 2.9625e-05
# Epoch 191/1000
#  - 16s - loss: 3.1578e-04 - mean_squared_error: 3.1578e-04 - val_loss: 2.5164e-05 - val_mean_squared_error: 2.5164e-05
# Epoch 192/1000
#  - 17s - loss: 3.1500e-04 - mean_squared_error: 3.1500e-04 - val_loss: 2.7742e-05 - val_mean_squared_error: 2.7742e-05
# Epoch 193/1000
#  - 17s - loss: 3.1505e-04 - mean_squared_error: 3.1505e-04 - val_loss: 2.6701e-05 - val_mean_squared_error: 2.6701e-05
# Epoch 194/1000
#  - 18s - loss: 3.1524e-04 - mean_squared_error: 3.1524e-04 - val_loss: 2.5210e-05 - val_mean_squared_error: 2.5210e-05
# Epoch 195/1000
#  - 17s - loss: 3.1508e-04 - mean_squared_error: 3.1508e-04 - val_loss: 2.6923e-05 - val_mean_squared_error: 2.6923e-05
# Epoch 196/1000
#  - 17s - loss: 3.1513e-04 - mean_squared_error: 3.1513e-04 - val_loss: 2.6057e-05 - val_mean_squared_error: 2.6057e-05
# Epoch 197/1000
#  - 17s - loss: 3.1519e-04 - mean_squared_error: 3.1519e-04 - val_loss: 2.5667e-05 - val_mean_squared_error: 2.5667e-05
# Epoch 198/1000
#  - 18s - loss: 3.1506e-04 - mean_squared_error: 3.1506e-04 - val_loss: 2.5263e-05 - val_mean_squared_error: 2.5263e-05
# Epoch 199/1000

# %%
predict()

# %%
a = mpimg.imread('butterfly_GT.bmp')
plt.imshow(a)
del(a)
