# %%
from keras.models import Sequential
from keras.layers import Conv2D, Input, BatchNormalization
from keras.callbacks import ModelCheckpoint, Callback
from keras.optimizers import SGD, Adam
from keras.utils.training_utils import multi_gpu_model
from keras.preprocessing.image import ImageDataGenerator
from keras import initializers
import prepare_data as pd
import numpy
import math
import scipy.misc as spm

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from PIL import Image

from lr_multiplier import LearningRateMultiplier

import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.2
set_session(tf.Session(config=config))
# Out:
# Using TensorFlow backend.

# %%
# see example https://github.com/keras-team/keras/issues/8649
class MyCbk(Callback):

    def __init__(self, model):
         self.model_to_save = model

    def on_epoch_end(self, epoch, logs=None):
        self.model_to_save.save('checkpoints/64-9-3-5_128-64-SRCNN_model_at_epoch_%d.h5' % epoch)

# %%
def psnr(target, ref):

    target_data = numpy.array(target, dtype=float)
    ref_data = numpy.array(ref, dtype=float)

    diff = ref_data - target_data
    diff = diff.flatten('C')

    rmse = math.sqrt(numpy.mean(diff ** 2.))

    return 20 * math.log10(255. / rmse)

# %%
def model(optimizer='SGD', all_layers=True, processing='GPU', lr=0.0001):

    multipliers = {'conv2d_1': 1, 'conv2d_2': 1, 'conv2d_3': 0.1}
    
    optimizer = optimizer.upper()
    processing = processing.upper()
    
    print('Using {}.'.format(optimizer))

    if optimizer == 'SGD' and all_layers:
        opt = LearningRateMultiplier(SGD, lr_multipliers=multipliers, lr=lr)
    elif optimizer == 'SGD':
        opt = SGD(lr=0.0001)
    elif all_layers:
        opt = LearningRateMultiplier(Adam, lr_multipliers=multipliers, lr=lr)
    else:
        opt = Adam(lr=lr)
    
    SRCNN = Sequential()
    SRCNN.add(Conv2D(filters=128, kernel_size=(9, 9), 
                     kernel_initializer='glorot_uniform', bias_initializer='random_uniform',
                     activation='relu', padding='valid', use_bias=True, input_shape=(64, 64, 1), name='conv2d_1'))

    SRCNN.add(Conv2D(filters=64, kernel_size=(3, 3), 
                     kernel_initializer='glorot_uniform', bias_initializer='random_uniform',
                     activation='relu', padding='same', use_bias=True, name='conv2d_2'))
    
    SRCNN.add(Conv2D(filters=1, kernel_size=(5, 5),
                     kernel_initializer='glorot_uniform', bias_initializer='random_uniform',
                     activation='linear', padding='valid', use_bias=True,  name='conv2d_3'))
    SRCNN_MULTI = multi_gpu_model(SRCNN, gpus=8)
    if processing == 'GPU':    
        SRCNN_MULTI.compile(optimizer=opt, loss='mean_squared_error', metrics=['mean_squared_error'])
    else:
        SRCNN.compile(optimizer=opt, loss='mean_squared_error', metrics=['mean_squared_error'])
    return SRCNN, SRCNN_MULTI

# %%
def predict_model():

    sgd = SGD(lr=0.0001)
    
    SRCNN = Sequential()
    SRCNN.add(Conv2D(filters=128, kernel_size=(9, 9), 
                     kernel_initializer='glorot_uniform', bias_initializer='random_uniform',
                     activation='relu', padding='valid', use_bias=True, input_shape=(None, None, 1), name='conv2d_1'))
        
    SRCNN.add(Conv2D(filters=64, kernel_size=(3, 3), 
                     kernel_initializer='glorot_uniform', bias_initializer='random_uniform',
                     activation='relu', padding='same', use_bias=True, name='conv2d_2'))
        
    SRCNN.add(Conv2D(filters=1, kernel_size=(5, 5),
                     kernel_initializer='glorot_uniform', bias_initializer='random_uniform',
                     activation='linear', padding='valid', use_bias=True,  name='conv2d_3'))
    adam = Adam(lr=0.0003)
    sgd_last = SGD(lr=0.00001)

    SRCNN.compile(optimizer=adam, loss='mean_squared_error', metrics=['mean_squared_error'])
    return SRCNN

# %%
def train(processing='GPU', optimizer='SGD', use_data_augmentation=False, epochs=200, lr=0.0001):

    optimizer = optimizer.upper()
    processing = processing.upper()
    
    srcnn_model, srcnn_multi_model = model(optimizer=optimizer, processing=processing, lr=lr)

    callbacks_list = []
    BS = 1024
    
    if processing == 'GPU' or use_data_augmentation:    
        print(srcnn_multi_model.summary())
        # see example https://github.com/keras-team/keras/issues/8649
        cbk = MyCbk(srcnn_model)
        
    else:
        print(srcnn_model.summary())
        checkpoint = ModelCheckpoint("64SRCNN_check.h5", monitor='val_loss', 
                                     verbose=2, 
                                     save_best_only=True,
                                     save_weights_only=False)
        callbacks_list.append(checkpoint)
        
    data, label = pd.read_training_data("./64crop_train.h5")
    val_data, val_label = pd.read_training_data("./64test.h5")

    max_value = data.max()

    data = data/max_value
    label = label/max_value

    val_data = val_data/max_value
    val_label = val_label/max_value

    
    # construct the training image generator for data augmentation
    datagen = ImageDataGenerator(rotation_range=45,
                                 zoom_range=0.15,
                                 width_shift_range=0.2,
                                 height_shift_range=0.2,
                                 horizontal_flip=True, 
                                 vertical_flip=True)

    if use_data_augmentation and processing == 'GPU':
        history = srcnn_multi_model.fit_generator(datagen.flow(data, label, batch_size=BS),
                                                    validation_data=(val_data, val_label),
                                                    steps_per_epoch=len(data) // BS,
                                                    epochs=epochs, 
                                                    verbose=2, 
                                                    shuffle=True,
                                                    callbacks=[cbk],
                                                    use_multiprocessing=True)
    elif processing == 'GPU':
        srcnn_multi_model.fit(data, label, batch_size=BS,
                              validation_split=0.2,
                              shuffle=True, 
                              epochs=epochs, 
                              verbose=2,
                              callbacks=[cbk])
    elif use_data_augmentation:
        history = srcnn_model.fit_generator(datagen.flow(data, label, batch_size=BS),
                                          validation_data=(val_data, val_label),
                                          steps_per_epoch=len(data) // BS,
                                          epochs=epochs, 
                                          verbose=2, 
                                          shuffle=True,
                                          callbacks=[cbk])
    else:
        srcnn_model.fit(data, label, batch_size=BS,
                        validation_split=0.2,
                        shuffle=True, 
                        epochs=epochs, 
                        verbose=2,
                        callbacks=callbacks_list)

# %%
data, label = pd.read_training_data("./64crop_train.h5")
val_data, val_label = pd.read_training_data("./64test.h5")

max_value = data.max()

data = data/max_value
label = label/max_value

val_data = val_data/max_value
val_label = val_label/max_value

# %%
def predict():

    srcnn_model = predict_model()
    srcnn_model.load_weights("checkpoints/64-9-3-5_128-64-SRCNN_model_at_epoch_999.h5")
    IMG_NAME = numpy.fromfile('ground_data/pick/recon/slice_256.b', dtype = 'uint8')
    INPUT_NAME = numpy.fromfile("sub_data/pick/recon/slice_256.b", dtype = 'uint8')
    OUTPUT_NAME = "pre2.png"

    dimension_img = int(IMG_NAME.shape[0]**(1/2))
    dimension_input = int(INPUT_NAME.shape[0]**(1/2))
    
    IMG_NAME = IMG_NAME.reshape((dimension_img, dimension_img))
    INPUT_NAME = INPUT_NAME.reshape((dimension_input, dimension_input))
    
    import cv2
    img = INPUT_NAME.copy()
    shape = IMG_NAME.shape
    Y_img = img.copy()
    Y_img = spm.imresize(Y_img, size=shape, interp='bicubic')
    bicubic = Y_img.copy()

    Y_img = Y_img.reshape((dimension_img, dimension_img, 1))
    
    for i in range(Y_img.shape[-1]):
        Y = numpy.zeros((1, shape[0], shape[1], 1), dtype=float)
        Y[0,:,:,0] = Y_img[:,:,i].astype(float) / 255.
        pre = srcnn_model.predict(Y, batch_size=1) * 255.
        
    pre[pre[:] > 255] = 255
    pre[pre[:] < 0] = 0
    pre = pre.astype(float)
    print(Y_img.shape, pre.shape)
    Y_img[6: -6, 6: -6, 0] = pre[0, :, :, 0].copy()
    cv2.imwrite(OUTPUT_NAME, Y_img)

    # psnr calculation:
    im1 = IMG_NAME
    im2 = bicubic
    im3 = cv2.imread(OUTPUT_NAME)[:,:,0]
    
    print(im1.shape, im2.shape, im3.shape)

    print ("bicubic:")
    print (cv2.PSNR(im1, im2))
    print ("SRCNN:")
    print (cv2.PSNR(im1, im3))
    
    import matplotlib.pyplot as plt
    print(im1.shape)
    plt.figure(figsize=[15,30])
    plt.subplot(311)
    
    plt.title('Original')
    plt.imshow(im1)
    plt.subplot(312)

    plt.title('Bicubic')    
    plt.imshow(im2)
    plt.subplot(313)

    plt.title('SRCNN')
    plt.imshow(im3[10:-10,10:-10])
    plt.show()

# %%
train(processing='GPU', optimizer='adam', use_data_augmentation=False, epochs=1000, lr=0.0001)
# Out:
# Using ADAM.
# WARNING:tensorflow:From /home/ABTLUS/fernando.furusato/tests/jupyter/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# conv2d_1_input (InputLayer)     (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 64, 64, 1)    0           conv2d_1_input[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 64, 64, 1)    0           conv2d_1_input[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 64, 64, 1)    0           conv2d_1_input[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 64, 64, 1)    0           conv2d_1_input[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 64, 64, 1)    0           conv2d_1_input[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 64, 64, 1)    0           conv2d_1_input[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 64, 64, 1)    0           conv2d_1_input[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 64, 64, 1)    0           conv2d_1_input[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 52, 52, 1)    85889       lambda_1[0][0]
#                                                                  lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_7[0][0]
#                                                                  lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Concatenate)          (None, 52, 52, 1)    0           sequential_1[1][0]
#                                                                  sequential_1[2][0]
#                                                                  sequential_1[3][0]
#                                                                  sequential_1[4][0]
#                                                                  sequential_1[5][0]
#                                                                  sequential_1[6][0]
#                                                                  sequential_1[7][0]
#                                                                  sequential_1[8][0]
# ==================================================================================================
# Total params: 85,889
# Trainable params: 85,889
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From /home/ABTLUS/fernando.furusato/tests/jupyter/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 160563 samples, validate on 40141 samples
# Epoch 1/1000
#  - 32s - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 6.0024e-05 - val_mean_squared_error: 6.0024e-05
# Epoch 2/1000
#  - 16s - loss: 3.5502e-04 - mean_squared_error: 3.5502e-04 - val_loss: 2.5129e-05 - val_mean_squared_error: 2.5129e-05
# Epoch 3/1000
#  - 17s - loss: 3.4021e-04 - mean_squared_error: 3.4021e-04 - val_loss: 2.4352e-05 - val_mean_squared_error: 2.4352e-05
# Epoch 4/1000
#  - 17s - loss: 3.3884e-04 - mean_squared_error: 3.3884e-04 - val_loss: 2.4301e-05 - val_mean_squared_error: 2.4301e-05
# Epoch 5/1000
#  - 17s - loss: 3.3760e-04 - mean_squared_error: 3.3760e-04 - val_loss: 2.4303e-05 - val_mean_squared_error: 2.4303e-05
# Epoch 6/1000
#  - 16s - loss: 3.3392e-04 - mean_squared_error: 3.3392e-04 - val_loss: 2.4354e-05 - val_mean_squared_error: 2.4354e-05
# Epoch 7/1000
#  - 18s - loss: 3.2687e-04 - mean_squared_error: 3.2687e-04 - val_loss: 2.4613e-05 - val_mean_squared_error: 2.4613e-05
# Epoch 8/1000
#  - 16s - loss: 3.2297e-04 - mean_squared_error: 3.2297e-04 - val_loss: 2.5084e-05 - val_mean_squared_error: 2.5084e-05
# Epoch 9/1000
#  - 18s - loss: 3.2148e-04 - mean_squared_error: 3.2148e-04 - val_loss: 2.5008e-05 - val_mean_squared_error: 2.5008e-05
# Epoch 10/1000
#  - 17s - loss: 3.2074e-04 - mean_squared_error: 3.2074e-04 - val_loss: 2.5112e-05 - val_mean_squared_error: 2.5112e-05
# Epoch 11/1000
#  - 17s - loss: 3.2017e-04 - mean_squared_error: 3.2017e-04 - val_loss: 2.5167e-05 - val_mean_squared_error: 2.5167e-05
# Epoch 12/1000
#  - 17s - loss: 3.1974e-04 - mean_squared_error: 3.1974e-04 - val_loss: 2.5202e-05 - val_mean_squared_error: 2.5202e-05
# Epoch 13/1000
#  - 18s - loss: 3.1941e-04 - mean_squared_error: 3.1941e-04 - val_loss: 2.5253e-05 - val_mean_squared_error: 2.5253e-05
# Epoch 14/1000
#  - 17s - loss: 3.1908e-04 - mean_squared_error: 3.1908e-04 - val_loss: 2.5272e-05 - val_mean_squared_error: 2.5272e-05
# Epoch 15/1000
#  - 18s - loss: 3.1884e-04 - mean_squared_error: 3.1884e-04 - val_loss: 2.5291e-05 - val_mean_squared_error: 2.5291e-05
# Epoch 16/1000
#  - 17s - loss: 3.1867e-04 - mean_squared_error: 3.1867e-04 - val_loss: 2.5327e-05 - val_mean_squared_error: 2.5327e-05
# Epoch 17/1000
#  - 18s - loss: 3.1847e-04 - mean_squared_error: 3.1847e-04 - val_loss: 2.5324e-05 - val_mean_squared_error: 2.5324e-05
# Epoch 18/1000
#  - 18s - loss: 3.1831e-04 - mean_squared_error: 3.1831e-04 - val_loss: 2.5354e-05 - val_mean_squared_error: 2.5354e-05
# Epoch 19/1000
#  - 18s - loss: 3.1821e-04 - mean_squared_error: 3.1821e-04 - val_loss: 2.5357e-05 - val_mean_squared_error: 2.5357e-05
# Epoch 20/1000
#  - 17s - loss: 3.1809e-04 - mean_squared_error: 3.1809e-04 - val_loss: 2.5371e-05 - val_mean_squared_error: 2.5371e-05
# Epoch 21/1000
#  - 17s - loss: 3.1770e-04 - mean_squared_error: 3.1770e-04 - val_loss: 2.5441e-05 - val_mean_squared_error: 2.5441e-05
# Epoch 27/1000
#  - 18s - loss: 3.1761e-04 - mean_squared_error: 3.1761e-04 - val_loss: 2.5425e-05 - val_mean_squared_error: 2.5425e-05
# Epoch 28/1000
#  - 17s - loss: 3.1762e-04 - mean_squared_error: 3.1762e-04 - val_loss: 2.5476e-05 - val_mean_squared_error: 2.5476e-05
# Epoch 29/1000
#  - 17s - loss: 3.1754e-04 - mean_squared_error: 3.1754e-04 - val_loss: 2.5438e-05 - val_mean_squared_error: 2.5438e-05
# Epoch 30/1000
#  - 16s - loss: 3.1752e-04 - mean_squared_error: 3.1752e-04 - val_loss: 2.5468e-05 - val_mean_squared_error: 2.5468e-05
# Epoch 31/1000
#  - 18s - loss: 3.1750e-04 - mean_squared_error: 3.1750e-04 - val_loss: 2.5549e-05 - val_mean_squared_error: 2.5549e-05
# Epoch 32/1000
#  - 17s - loss: 3.1750e-04 - mean_squared_error: 3.1750e-04 - val_loss: 2.5459e-05 - val_mean_squared_error: 2.5459e-05
# Epoch 33/1000
#  - 18s - loss: 3.1749e-04 - mean_squared_error: 3.1749e-04 - val_loss: 2.5462e-05 - val_mean_squared_error: 2.5462e-05
# Epoch 34/1000
#  - 16s - loss: 3.1741e-04 - mean_squared_error: 3.1741e-04 - val_loss: 2.5796e-05 - val_mean_squared_error: 2.5796e-05
# Epoch 35/1000
#  - 18s - loss: 3.1751e-04 - mean_squared_error: 3.1751e-04 - val_loss: 2.5611e-05 - val_mean_squared_error: 2.5611e-05
# Epoch 36/1000
#  - 17s - loss: 3.1741e-04 - mean_squared_error: 3.1741e-04 - val_loss: 2.6029e-05 - val_mean_squared_error: 2.6029e-05
# Epoch 37/1000
#  - 18s - loss: 3.1756e-04 - mean_squared_error: 3.1756e-04 - val_loss: 2.5467e-05 - val_mean_squared_error: 2.5467e-05
# Epoch 38/1000
#  - 17s - loss: 3.1749e-04 - mean_squared_error: 3.1749e-04 - val_loss: 2.5495e-05 - val_mean_squared_error: 2.5495e-05
# Epoch 39/1000
#  - 17s - loss: 3.1757e-04 - mean_squared_error: 3.1757e-04 - val_loss: 2.5675e-05 - val_mean_squared_error: 2.5675e-05
# Epoch 40/1000
#  - 16s - loss: 3.1748e-04 - mean_squared_error: 3.1748e-04 - val_loss: 2.6011e-05 - val_mean_squared_error: 2.6011e-05
# Epoch 41/1000
#  - 18s - loss: 3.1776e-04 - mean_squared_error: 3.1776e-04 - val_loss: 2.5487e-05 - val_mean_squared_error: 2.5487e-05
# Epoch 42/1000
#  - 17s - loss: 3.1758e-04 - mean_squared_error: 3.1758e-04 - val_loss: 2.5816e-05 - val_mean_squared_error: 2.5816e-05
# Epoch 43/1000
#  - 17s - loss: 3.1757e-04 - mean_squared_error: 3.1757e-04 - val_loss: 2.5517e-05 - val_mean_squared_error: 2.5517e-05
# Epoch 44/1000
#  - 16s - loss: 3.1815e-04 - mean_squared_error: 3.1815e-04 - val_loss: 2.5553e-05 - val_mean_squared_error: 2.5553e-05
# Epoch 45/1000
#  - 18s - loss: 3.1741e-04 - mean_squared_error: 3.1741e-04 - val_loss: 2.7444e-05 - val_mean_squared_error: 2.7444e-05
# Epoch 46/1000
#  - 16s - loss: 3.1779e-04 - mean_squared_error: 3.1779e-04 - val_loss: 2.5931e-05 - val_mean_squared_error: 2.5931e-05
# Epoch 47/1000
#  - 17s - loss: 3.1773e-04 - mean_squared_error: 3.1773e-04 - val_loss: 2.6951e-05 - val_mean_squared_error: 2.6951e-05
# Epoch 48/1000
#  - 17s - loss: 3.1786e-04 - mean_squared_error: 3.1786e-04 - val_loss: 2.5488e-05 - val_mean_squared_error: 2.5488e-05
# Epoch 49/1000
#  - 18s - loss: 3.1774e-04 - mean_squared_error: 3.1774e-04 - val_loss: 2.5626e-05 - val_mean_squared_error: 2.5626e-05
# Epoch 50/1000
#  - 17s - loss: 3.1779e-04 - mean_squared_error: 3.1779e-04 - val_loss: 2.5520e-05 - val_mean_squared_error: 2.5520e-05
# Epoch 51/1000
#  - 18s - loss: 3.1816e-04 - mean_squared_error: 3.1816e-04 - val_loss: 2.5495e-05 - val_mean_squared_error: 2.5495e-05
# Epoch 52/1000
#  - 17s - loss: 3.1730e-04 - mean_squared_error: 3.1730e-04 - val_loss: 2.5630e-05 - val_mean_squared_error: 2.5630e-05
# Epoch 53/1000
#  - 18s - loss: 3.1802e-04 - mean_squared_error: 3.1802e-04 - val_loss: 2.5517e-05 - val_mean_squared_error: 2.5517e-05
# Epoch 54/1000
#  - 17s - loss: 3.1774e-04 - mean_squared_error: 3.1774e-04 - val_loss: 3.0789e-05 - val_mean_squared_error: 3.0789e-05
# Epoch 55/1000
#  - 18s - loss: 3.1774e-04 - mean_squared_error: 3.1774e-04 - val_loss: 2.7002e-05 - val_mean_squared_error: 2.7002e-05
# Epoch 56/1000
#  - 17s - loss: 3.1781e-04 - mean_squared_error: 3.1781e-04 - val_loss: 2.6293e-05 - val_mean_squared_error: 2.6293e-05
# Epoch 57/1000
#  - 18s - loss: 3.1773e-04 - mean_squared_error: 3.1773e-04 - val_loss: 2.6229e-05 - val_mean_squared_error: 2.6229e-05
# Epoch 58/1000
#  - 17s - loss: 3.1785e-04 - mean_squared_error: 3.1785e-04 - val_loss: 2.5554e-05 - val_mean_squared_error: 2.5554e-05
# Epoch 59/1000
#  - 18s - loss: 3.1759e-04 - mean_squared_error: 3.1759e-04 - val_loss: 3.2492e-05 - val_mean_squared_error: 3.2492e-05
# Epoch 60/1000
#  - 17s - loss: 3.1780e-04 - mean_squared_error: 3.1780e-04 - val_loss: 2.5575e-05 - val_mean_squared_error: 2.5575e-05
# Epoch 61/1000
#  - 18s - loss: 3.1755e-04 - mean_squared_error: 3.1755e-04 - val_loss: 2.5972e-05 - val_mean_squared_error: 2.5972e-05
# Epoch 62/1000
#  - 17s - loss: 3.1759e-04 - mean_squared_error: 3.1759e-04 - val_loss: 2.5549e-05 - val_mean_squared_error: 2.5549e-05
# Epoch 63/1000
#  - 18s - loss: 3.1760e-04 - mean_squared_error: 3.1760e-04 - val_loss: 2.5576e-05 - val_mean_squared_error: 2.5576e-05
# Epoch 64/1000
#  - 17s - loss: 3.1771e-04 - mean_squared_error: 3.1771e-04 - val_loss: 2.5885e-05 - val_mean_squared_error: 2.5885e-05
# Epoch 65/1000
#  - 19s - loss: 3.1773e-04 - mean_squared_error: 3.1773e-04 - val_loss: 2.6381e-05 - val_mean_squared_error: 2.6381e-05
# Epoch 66/1000
#  - 17s - loss: 3.1768e-04 - mean_squared_error: 3.1768e-04 - val_loss: 2.5750e-05 - val_mean_squared_error: 2.5750e-05
# Epoch 67/1000
#  - 18s - loss: 3.1740e-04 - mean_squared_error: 3.1740e-04 - val_loss: 2.5530e-05 - val_mean_squared_error: 2.5530e-05
# Epoch 68/1000
#  - 17s - loss: 3.1741e-04 - mean_squared_error: 3.1741e-04 - val_loss: 2.5738e-05 - val_mean_squared_error: 2.5738e-05
# Epoch 69/1000
#  - 18s - loss: 3.1765e-04 - mean_squared_error: 3.1765e-04 - val_loss: 2.7486e-05 - val_mean_squared_error: 2.7486e-05
# Epoch 70/1000
#  - 17s - loss: 3.1757e-04 - mean_squared_error: 3.1757e-04 - val_loss: 2.6766e-05 - val_mean_squared_error: 2.6766e-05
# Epoch 71/1000
#  - 18s - loss: 3.1743e-04 - mean_squared_error: 3.1743e-04 - val_loss: 2.6510e-05 - val_mean_squared_error: 2.6510e-05
# Epoch 72/1000
#  - 17s - loss: 3.1739e-04 - mean_squared_error: 3.1739e-04 - val_loss: 2.8265e-05 - val_mean_squared_error: 2.8265e-05
# Epoch 73/1000
#  - 18s - loss: 3.1774e-04 - mean_squared_error: 3.1774e-04 - val_loss: 2.5532e-05 - val_mean_squared_error: 2.5532e-05
# Epoch 74/1000
#  - 17s - loss: 3.1736e-04 - mean_squared_error: 3.1736e-04 - val_loss: 2.5600e-05 - val_mean_squared_error: 2.5600e-05
# Epoch 75/1000
#  - 18s - loss: 3.1720e-04 - mean_squared_error: 3.1720e-04 - val_loss: 2.5768e-05 - val_mean_squared_error: 2.5768e-05
# Epoch 76/1000
#  - 17s - loss: 3.1757e-04 - mean_squared_error: 3.1757e-04 - val_loss: 2.5536e-05 - val_mean_squared_error: 2.5536e-05
# Epoch 77/1000
#  - 18s - loss: 3.1719e-04 - mean_squared_error: 3.1719e-04 - val_loss: 2.8872e-05 - val_mean_squared_error: 2.8872e-05
# Epoch 78/1000
#  - 17s - loss: 3.1763e-04 - mean_squared_error: 3.1763e-04 - val_loss: 2.5537e-05 - val_mean_squared_error: 2.5537e-05
# Epoch 79/1000
#  - 18s - loss: 3.1749e-04 - mean_squared_error: 3.1749e-04 - val_loss: 2.5619e-05 - val_mean_squared_error: 2.5619e-05
# Epoch 80/1000
#  - 17s - loss: 3.1719e-04 - mean_squared_error: 3.1719e-04 - val_loss: 2.5740e-05 - val_mean_squared_error: 2.5740e-05
# Epoch 81/1000
#  - 18s - loss: 3.1721e-04 - mean_squared_error: 3.1721e-04 - val_loss: 2.6043e-05 - val_mean_squared_error: 2.6043e-05
# Epoch 82/1000
#  - 17s - loss: 3.1778e-04 - mean_squared_error: 3.1778e-04 - val_loss: 2.7257e-05 - val_mean_squared_error: 2.7257e-05
# Epoch 83/1000
#  - 17s - loss: 3.1713e-04 - mean_squared_error: 3.1713e-04 - val_loss: 2.5846e-05 - val_mean_squared_error: 2.5846e-05
# Epoch 84/1000
#  - 17s - loss: 3.1714e-04 - mean_squared_error: 3.1714e-04 - val_loss: 2.6096e-05 - val_mean_squared_error: 2.6096e-05
# Epoch 85/1000
#  - 18s - loss: 3.1726e-04 - mean_squared_error: 3.1726e-04 - val_loss: 2.7971e-05 - val_mean_squared_error: 2.7971e-05
# Epoch 86/1000
#  - 17s - loss: 3.1736e-04 - mean_squared_error: 3.1736e-04 - val_loss: 2.5644e-05 - val_mean_squared_error: 2.5644e-05
# Epoch 87/1000
#  - 18s - loss: 3.1720e-04 - mean_squared_error: 3.1720e-04 - val_loss: 2.5552e-05 - val_mean_squared_error: 2.5552e-05
# Epoch 88/1000
#  - 17s - loss: 3.1727e-04 - mean_squared_error: 3.1727e-04 - val_loss: 2.6539e-05 - val_mean_squared_error: 2.6539e-05
# Epoch 89/1000
#  - 18s - loss: 3.1719e-04 - mean_squared_error: 3.1719e-04 - val_loss: 2.6183e-05 - val_mean_squared_error: 2.6183e-05
# Epoch 90/1000
#  - 17s - loss: 3.1739e-04 - mean_squared_error: 3.1739e-04 - val_loss: 2.5747e-05 - val_mean_squared_error: 2.5747e-05
# Epoch 91/1000
#  - 18s - loss: 3.1703e-04 - mean_squared_error: 3.1703e-04 - val_loss: 2.5559e-05 - val_mean_squared_error: 2.5559e-05
# Epoch 92/1000
#  - 17s - loss: 3.1715e-04 - mean_squared_error: 3.1715e-04 - val_loss: 2.5914e-05 - val_mean_squared_error: 2.5914e-05
# Epoch 93/1000
#  - 18s - loss: 3.1729e-04 - mean_squared_error: 3.1729e-04 - val_loss: 2.5564e-05 - val_mean_squared_error: 2.5564e-05
# Epoch 94/1000
#  - 17s - loss: 3.1711e-04 - mean_squared_error: 3.1711e-04 - val_loss: 2.5862e-05 - val_mean_squared_error: 2.5862e-05
# Epoch 95/1000
#  - 18s - loss: 3.1714e-04 - mean_squared_error: 3.1714e-04 - val_loss: 2.6590e-05 - val_mean_squared_error: 2.6590e-05
# Epoch 96/1000
#  - 16s - loss: 3.1732e-04 - mean_squared_error: 3.1732e-04 - val_loss: 2.6061e-05 - val_mean_squared_error: 2.6061e-05
# Epoch 97/1000
#  - 18s - loss: 3.1708e-04 - mean_squared_error: 3.1708e-04 - val_loss: 2.5743e-05 - val_mean_squared_error: 2.5743e-05
# Epoch 98/1000
#  - 17s - loss: 3.1730e-04 - mean_squared_error: 3.1730e-04 - val_loss: 2.9439e-05 - val_mean_squared_error: 2.9439e-05
# Epoch 99/1000
#  - 18s - loss: 3.1731e-04 - mean_squared_error: 3.1731e-04 - val_loss: 2.5711e-05 - val_mean_squared_error: 2.5711e-05
# Epoch 100/1000
#  - 17s - loss: 3.1664e-04 - mean_squared_error: 3.1664e-04 - val_loss: 2.5791e-05 - val_mean_squared_error: 2.5791e-05
# Epoch 101/1000
#  - 17s - loss: 3.1713e-04 - mean_squared_error: 3.1713e-04 - val_loss: 2.6255e-05 - val_mean_squared_error: 2.6255e-05
# Epoch 102/1000
#  - 17s - loss: 3.1716e-04 - mean_squared_error: 3.1716e-04 - val_loss: 2.5746e-05 - val_mean_squared_error: 2.5746e-05
# Epoch 103/1000
#  - 18s - loss: 3.1707e-04 - mean_squared_error: 3.1707e-04 - val_loss: 2.5936e-05 - val_mean_squared_error: 2.5936e-05
# Epoch 104/1000
#  - 17s - loss: 3.1732e-04 - mean_squared_error: 3.1732e-04 - val_loss: 2.5648e-05 - val_mean_squared_error: 2.5648e-05
# Epoch 105/1000
#  - 18s - loss: 3.1686e-04 - mean_squared_error: 3.1686e-04 - val_loss: 2.5969e-05 - val_mean_squared_error: 2.5969e-05
# Epoch 106/1000
#  - 17s - loss: 3.1694e-04 - mean_squared_error: 3.1694e-04 - val_loss: 2.5613e-05 - val_mean_squared_error: 2.5613e-05
# Epoch 107/1000
#  - 18s - loss: 3.1732e-04 - mean_squared_error: 3.1732e-04 - val_loss: 2.5713e-05 - val_mean_squared_error: 2.5713e-05
# Epoch 108/1000
#  - 17s - loss: 3.1699e-04 - mean_squared_error: 3.1699e-04 - val_loss: 2.6053e-05 - val_mean_squared_error: 2.6053e-05
# Epoch 109/1000
#  - 18s - loss: 3.1702e-04 - mean_squared_error: 3.1702e-04 - val_loss: 2.7137e-05 - val_mean_squared_error: 2.7137e-05
# Epoch 110/1000
#  - 17s - loss: 3.1709e-04 - mean_squared_error: 3.1709e-04 - val_loss: 2.5978e-05 - val_mean_squared_error: 2.5978e-05
# Epoch 111/1000
#  - 18s - loss: 3.1679e-04 - mean_squared_error: 3.1679e-04 - val_loss: 2.5575e-05 - val_mean_squared_error: 2.5575e-05
# Epoch 112/1000
#  - 17s - loss: 3.1681e-04 - mean_squared_error: 3.1681e-04 - val_loss: 2.5575e-05 - val_mean_squared_error: 2.5575e-05
# Epoch 113/1000
#  - 18s - loss: 3.1710e-04 - mean_squared_error: 3.1710e-04 - val_loss: 2.5667e-05 - val_mean_squared_error: 2.5667e-05
# Epoch 114/1000
#  - 17s - loss: 3.1708e-04 - mean_squared_error: 3.1708e-04 - val_loss: 2.5963e-05 - val_mean_squared_error: 2.5963e-05
# Epoch 115/1000
#  - 17s - loss: 3.1682e-04 - mean_squared_error: 3.1682e-04 - val_loss: 3.0237e-05 - val_mean_squared_error: 3.0237e-05
# Epoch 116/1000
#  - 16s - loss: 3.1699e-04 - mean_squared_error: 3.1699e-04 - val_loss: 2.5682e-05 - val_mean_squared_error: 2.5682e-05
# Epoch 117/1000
#  - 17s - loss: 3.1709e-04 - mean_squared_error: 3.1709e-04 - val_loss: 2.5689e-05 - val_mean_squared_error: 2.5689e-05
# Epoch 118/1000
#  - 16s - loss: 3.1706e-04 - mean_squared_error: 3.1706e-04 - val_loss: 4.0440e-05 - val_mean_squared_error: 4.0440e-05
# Epoch 119/1000
#  - 18s - loss: 3.1673e-04 - mean_squared_error: 3.1673e-04 - val_loss: 2.5596e-05 - val_mean_squared_error: 2.5596e-05
# Epoch 120/1000
#  - 17s - loss: 3.1695e-04 - mean_squared_error: 3.1695e-04 - val_loss: 2.5600e-05 - val_mean_squared_error: 2.5600e-05
# Epoch 121/1000
#  - 18s - loss: 3.1673e-04 - mean_squared_error: 3.1673e-04 - val_loss: 2.5826e-05 - val_mean_squared_error: 2.5826e-05
# Epoch 122/1000
#  - 17s - loss: 3.1706e-04 - mean_squared_error: 3.1706e-04 - val_loss: 2.5707e-05 - val_mean_squared_error: 2.5707e-05
# Epoch 123/1000
#  - 18s - loss: 3.1674e-04 - mean_squared_error: 3.1674e-04 - val_loss: 2.5978e-05 - val_mean_squared_error: 2.5978e-05
# Epoch 124/1000
#  - 17s - loss: 3.1677e-04 - mean_squared_error: 3.1677e-04 - val_loss: 2.5556e-05 - val_mean_squared_error: 2.5556e-05
# Epoch 125/1000
#  - 18s - loss: 3.1682e-04 - mean_squared_error: 3.1682e-04 - val_loss: 2.8334e-05 - val_mean_squared_error: 2.8334e-05
# Epoch 126/1000
#  - 17s - loss: 3.1673e-04 - mean_squared_error: 3.1673e-04 - val_loss: 2.6527e-05 - val_mean_squared_error: 2.6527e-05
# Epoch 127/1000
#  - 18s - loss: 3.1676e-04 - mean_squared_error: 3.1676e-04 - val_loss: 2.5609e-05 - val_mean_squared_error: 2.5609e-05
# Epoch 128/1000
#  - 17s - loss: 3.1674e-04 - mean_squared_error: 3.1674e-04 - val_loss: 2.5572e-05 - val_mean_squared_error: 2.5572e-05
# Epoch 129/1000
#  - 18s - loss: 3.1675e-04 - mean_squared_error: 3.1675e-04 - val_loss: 2.5860e-05 - val_mean_squared_error: 2.5860e-05
# Epoch 130/1000
#  - 17s - loss: 3.1653e-04 - mean_squared_error: 3.1653e-04 - val_loss: 2.6383e-05 - val_mean_squared_error: 2.6383e-05
# Epoch 131/1000
#  - 18s - loss: 3.1658e-04 - mean_squared_error: 3.1658e-04 - val_loss: 2.6273e-05 - val_mean_squared_error: 2.6273e-05
# Epoch 132/1000
#  - 17s - loss: 3.1672e-04 - mean_squared_error: 3.1672e-04 - val_loss: 2.5887e-05 - val_mean_squared_error: 2.5887e-05
# Epoch 133/1000
#  - 18s - loss: 3.1648e-04 - mean_squared_error: 3.1648e-04 - val_loss: 2.5590e-05 - val_mean_squared_error: 2.5590e-05
# Epoch 134/1000
#  - 17s - loss: 3.1618e-04 - mean_squared_error: 3.1618e-04 - val_loss: 2.6212e-05 - val_mean_squared_error: 2.6212e-05
# Epoch 135/1000
#  - 18s - loss: 3.1678e-04 - mean_squared_error: 3.1678e-04 - val_loss: 2.5506e-05 - val_mean_squared_error: 2.5506e-05
# Epoch 136/1000
#  - 17s - loss: 3.1622e-04 - mean_squared_error: 3.1622e-04 - val_loss: 2.6326e-05 - val_mean_squared_error: 2.6326e-05
# Epoch 137/1000
#  - 18s - loss: 3.1607e-04 - mean_squared_error: 3.1607e-04 - val_loss: 2.5650e-05 - val_mean_squared_error: 2.5650e-05
# Epoch 138/1000
#  - 17s - loss: 3.1652e-04 - mean_squared_error: 3.1652e-04 - val_loss: 2.5765e-05 - val_mean_squared_error: 2.5765e-05
# Epoch 139/1000
#  - 17s - loss: 3.1598e-04 - mean_squared_error: 3.1598e-04 - val_loss: 2.5483e-05 - val_mean_squared_error: 2.5483e-05
# Epoch 140/1000
#  - 16s - loss: 3.1616e-04 - mean_squared_error: 3.1616e-04 - val_loss: 2.5913e-05 - val_mean_squared_error: 2.5913e-05
# Epoch 141/1000
#  - 18s - loss: 3.1609e-04 - mean_squared_error: 3.1609e-04 - val_loss: 2.5486e-05 - val_mean_squared_error: 2.5486e-05
# Epoch 142/1000
#  - 17s - loss: 3.1598e-04 - mean_squared_error: 3.1598e-04 - val_loss: 2.5622e-05 - val_mean_squared_error: 2.5622e-05
# Epoch 143/1000
#  - 18s - loss: 3.1602e-04 - mean_squared_error: 3.1602e-04 - val_loss: 2.5557e-05 - val_mean_squared_error: 2.5557e-05
# Epoch 144/1000
#  - 17s - loss: 3.1592e-04 - mean_squared_error: 3.1592e-04 - val_loss: 2.5434e-05 - val_mean_squared_error: 2.5434e-05
# Epoch 145/1000
#  - 18s - loss: 3.1597e-04 - mean_squared_error: 3.1597e-04 - val_loss: 2.5757e-05 - val_mean_squared_error: 2.5757e-05
# Epoch 146/1000
#  - 17s - loss: 3.1586e-04 - mean_squared_error: 3.1586e-04 - val_loss: 2.5498e-05 - val_mean_squared_error: 2.5498e-05
# Epoch 147/1000
#  - 18s - loss: 3.1569e-04 - mean_squared_error: 3.1569e-04 - val_loss: 2.5494e-05 - val_mean_squared_error: 2.5494e-05
# Epoch 148/1000
#  - 17s - loss: 3.1611e-04 - mean_squared_error: 3.1611e-04 - val_loss: 2.7047e-05 - val_mean_squared_error: 2.7047e-05
# Epoch 149/1000
#  - 18s - loss: 3.1533e-04 - mean_squared_error: 3.1533e-04 - val_loss: 2.6008e-05 - val_mean_squared_error: 2.6008e-05
# Epoch 150/1000
#  - 17s - loss: 3.1574e-04 - mean_squared_error: 3.1574e-04 - val_loss: 2.5515e-05 - val_mean_squared_error: 2.5515e-05
# Epoch 151/1000
#  - 18s - loss: 3.1564e-04 - mean_squared_error: 3.1564e-04 - val_loss: 2.5518e-05 - val_mean_squared_error: 2.5518e-05
# Epoch 152/1000
#  - 17s - loss: 3.1556e-04 - mean_squared_error: 3.1556e-04 - val_loss: 2.5649e-05 - val_mean_squared_error: 2.5649e-05
# Epoch 153/1000
#  - 18s - loss: 3.1554e-04 - mean_squared_error: 3.1554e-04 - val_loss: 2.6235e-05 - val_mean_squared_error: 2.6235e-05
# Epoch 154/1000
#  - 16s - loss: 3.1572e-04 - mean_squared_error: 3.1572e-04 - val_loss: 2.5389e-05 - val_mean_squared_error: 2.5389e-05
# Epoch 155/1000
#  - 18s - loss: 3.1542e-04 - mean_squared_error: 3.1542e-04 - val_loss: 2.5650e-05 - val_mean_squared_error: 2.5650e-05
# Epoch 156/1000
#  - 17s - loss: 3.1520e-04 - mean_squared_error: 3.1520e-04 - val_loss: 2.6487e-05 - val_mean_squared_error: 2.6487e-05
# Epoch 157/1000
#  - 18s - loss: 3.1547e-04 - mean_squared_error: 3.1547e-04 - val_loss: 2.7127e-05 - val_mean_squared_error: 2.7127e-05
# Epoch 158/1000
#  - 17s - loss: 3.1542e-04 - mean_squared_error: 3.1542e-04 - val_loss: 2.6639e-05 - val_mean_squared_error: 2.6639e-05
# Epoch 159/1000
#  - 18s - loss: 3.1519e-04 - mean_squared_error: 3.1519e-04 - val_loss: 2.5603e-05 - val_mean_squared_error: 2.5603e-05
# Epoch 160/1000
#  - 17s - loss: 3.1531e-04 - mean_squared_error: 3.1531e-04 - val_loss: 2.6019e-05 - val_mean_squared_error: 2.6019e-05
# Epoch 161/1000
#  - 18s - loss: 3.1523e-04 - mean_squared_error: 3.1523e-04 - val_loss: 2.5988e-05 - val_mean_squared_error: 2.5988e-05
# Epoch 162/1000
#  - 17s - loss: 3.1530e-04 - mean_squared_error: 3.1530e-04 - val_loss: 2.6570e-05 - val_mean_squared_error: 2.6570e-05
# Epoch 163/1000
#  - 18s - loss: 3.1523e-04 - mean_squared_error: 3.1523e-04 - val_loss: 2.5459e-05 - val_mean_squared_error: 2.5459e-05
# Epoch 164/1000
#  - 17s - loss: 3.1528e-04 - mean_squared_error: 3.1528e-04 - val_loss: 2.5505e-05 - val_mean_squared_error: 2.5505e-05
# Epoch 165/1000
#  - 17s - loss: 3.1492e-04 - mean_squared_error: 3.1492e-04 - val_loss: 2.5649e-05 - val_mean_squared_error: 2.5649e-05
# Epoch 166/1000
#  - 17s - loss: 3.1526e-04 - mean_squared_error: 3.1526e-04 - val_loss: 2.7380e-05 - val_mean_squared_error: 2.7380e-05
# Epoch 167/1000
#  - 18s - loss: 3.1488e-04 - mean_squared_error: 3.1488e-04 - val_loss: 2.5580e-05 - val_mean_squared_error: 2.5580e-05
# Epoch 168/1000
#  - 16s - loss: 3.1504e-04 - mean_squared_error: 3.1504e-04 - val_loss: 2.5462e-05 - val_mean_squared_error: 2.5462e-05
# Epoch 169/1000
#  - 17s - loss: 3.1511e-04 - mean_squared_error: 3.1511e-04 - val_loss: 2.5442e-05 - val_mean_squared_error: 2.5442e-05
# Epoch 170/1000
#  - 17s - loss: 3.1503e-04 - mean_squared_error: 3.1503e-04 - val_loss: 2.5730e-05 - val_mean_squared_error: 2.5730e-05
# Epoch 171/1000
#  - 17s - loss: 3.1514e-04 - mean_squared_error: 3.1514e-04 - val_loss: 2.7740e-05 - val_mean_squared_error: 2.7740e-05
# Epoch 172/1000
#  - 17s - loss: 3.1511e-04 - mean_squared_error: 3.1511e-04 - val_loss: 3.2298e-05 - val_mean_squared_error: 3.2298e-05
# Epoch 173/1000
#  - 18s - loss: 3.1472e-04 - mean_squared_error: 3.1472e-04 - val_loss: 2.5278e-05 - val_mean_squared_error: 2.5278e-05
# Epoch 174/1000
#  - 17s - loss: 3.1493e-04 - mean_squared_error: 3.1493e-04 - val_loss: 2.5340e-05 - val_mean_squared_error: 2.5340e-05
# Epoch 175/1000
#  - 17s - loss: 3.1489e-04 - mean_squared_error: 3.1489e-04 - val_loss: 2.6070e-05 - val_mean_squared_error: 2.6070e-05
# Epoch 176/1000
#  - 16s - loss: 3.1488e-04 - mean_squared_error: 3.1488e-04 - val_loss: 2.5879e-05 - val_mean_squared_error: 2.5879e-05
# Epoch 177/1000
#  - 18s - loss: 3.1485e-04 - mean_squared_error: 3.1485e-04 - val_loss: 3.1289e-05 - val_mean_squared_error: 3.1289e-05
# Epoch 178/1000
#  - 17s - loss: 3.1485e-04 - mean_squared_error: 3.1485e-04 - val_loss: 2.5254e-05 - val_mean_squared_error: 2.5254e-05
# Epoch 179/1000
#  - 18s - loss: 3.1485e-04 - mean_squared_error: 3.1485e-04 - val_loss: 2.5934e-05 - val_mean_squared_error: 2.5934e-05
# Epoch 180/1000
#  - 17s - loss: 3.1483e-04 - mean_squared_error: 3.1483e-04 - val_loss: 2.5276e-05 - val_mean_squared_error: 2.5276e-05
# Epoch 181/1000
#  - 18s - loss: 3.1680e-04 - mean_squared_error: 3.1680e-04 - val_loss: 2.5244e-05 - val_mean_squared_error: 2.5244e-05
# Epoch 182/1000
#  - 17s - loss: 3.1413e-04 - mean_squared_error: 3.1413e-04 - val_loss: 2.5363e-05 - val_mean_squared_error: 2.5363e-05
# Epoch 183/1000
#  - 18s - loss: 3.1417e-04 - mean_squared_error: 3.1417e-04 - val_loss: 2.6511e-05 - val_mean_squared_error: 2.6511e-05
# Epoch 184/1000
#  - 16s - loss: 3.1460e-04 - mean_squared_error: 3.1460e-04 - val_loss: 2.5277e-05 - val_mean_squared_error: 2.5277e-05
# Epoch 185/1000
#  - 18s - loss: 3.1480e-04 - mean_squared_error: 3.1480e-04 - val_loss: 2.9698e-05 - val_mean_squared_error: 2.9698e-05
# Epoch 186/1000
#  - 17s - loss: 3.1468e-04 - mean_squared_error: 3.1468e-04 - val_loss: 2.5406e-05 - val_mean_squared_error: 2.5406e-05
# Epoch 187/1000
#  - 18s - loss: 3.1477e-04 - mean_squared_error: 3.1477e-04 - val_loss: 2.5546e-05 - val_mean_squared_error: 2.5546e-05
# Epoch 188/1000
#  - 17s - loss: 3.1472e-04 - mean_squared_error: 3.1472e-04 - val_loss: 2.7495e-05 - val_mean_squared_error: 2.7495e-05
# Epoch 189/1000
#  - 18s - loss: 3.1468e-04 - mean_squared_error: 3.1468e-04 - val_loss: 2.6053e-05 - val_mean_squared_error: 2.6053e-05
# Epoch 190/1000
#  - 17s - loss: 3.1451e-04 - mean_squared_error: 3.1451e-04 - val_loss: 2.7218e-05 - val_mean_squared_error: 2.7218e-05
# Epoch 191/1000
#  - 18s - loss: 3.1487e-04 - mean_squared_error: 3.1487e-04 - val_loss: 2.5240e-05 - val_mean_squared_error: 2.5240e-05
# Epoch 192/1000
#  - 16s - loss: 3.1477e-04 - mean_squared_error: 3.1477e-04 - val_loss: 2.5291e-05 - val_mean_squared_error: 2.5291e-05
# Epoch 193/1000
#  - 18s - loss: 3.1462e-04 - mean_squared_error: 3.1462e-04 - val_loss: 2.5229e-05 - val_mean_squared_error: 2.5229e-05
# Epoch 194/1000
#  - 17s - loss: 3.1458e-04 - mean_squared_error: 3.1458e-04 - val_loss: 2.5963e-05 - val_mean_squared_error: 2.5963e-05
# Epoch 195/1000
#  - 18s - loss: 3.1462e-04 - mean_squared_error: 3.1462e-04 - val_loss: 2.5481e-05 - val_mean_squared_error: 2.5481e-05
# Epoch 196/1000
#  - 17s - loss: 3.1459e-04 - mean_squared_error: 3.1459e-04 - val_loss: 2.8057e-05 - val_mean_squared_error: 2.8057e-05
# Epoch 197/1000
#  - 18s - loss: 3.1460e-04 - mean_squared_error: 3.1460e-04 - val_loss: 2.5393e-05 - val_mean_squared_error: 2.5393e-05
# Epoch 198/1000
#  - 17s - loss: 3.1456e-04 - mean_squared_error: 3.1456e-04 - val_loss: 2.5203e-05 - val_mean_squared_error: 2.5203e-05
# Epoch 199/1000
#  - 18s - loss: 3.1464e-04 - mean_squared_error: 3.1464e-04 - val_loss: 2.6496e-05 - val_mean_squared_error: 2.6496e-05
# Epoch 200/1000
#  - 17s - loss: 3.1461e-04 - mean_squared_error: 3.1461e-04 - val_loss: 2.5564e-05 - val_mean_squared_error: 2.5564e-05
# Epoch 201/1000
#  - 18s - loss: 3.1444e-04 - mean_squared_error: 3.1444e-04 - val_loss: 2.6239e-05 - val_mean_squared_error: 2.6239e-05
# Epoch 202/1000
#  - 17s - loss: 3.1466e-04 - mean_squared_error: 3.1466e-04 - val_loss: 2.5371e-05 - val_mean_squared_error: 2.5371e-05
# Epoch 203/1000
#  - 18s - loss: 3.1438e-04 - mean_squared_error: 3.1438e-04 - val_loss: 2.5267e-05 - val_mean_squared_error: 2.5267e-05
# Epoch 204/1000
#  - 17s - loss: 3.1438e-04 - mean_squared_error: 3.1438e-04 - val_loss: 2.5908e-05 - val_mean_squared_error: 2.5908e-05
# Epoch 205/1000
#  - 18s - loss: 3.1472e-04 - mean_squared_error: 3.1472e-04 - val_loss: 2.5238e-05 - val_mean_squared_error: 2.5238e-05
# Epoch 206/1000
#  - 17s - loss: 3.1586e-04 - mean_squared_error: 3.1586e-04 - val_loss: 2.5321e-05 - val_mean_squared_error: 2.5321e-05
# Epoch 207/1000
#  - 18s - loss: 3.1392e-04 - mean_squared_error: 3.1392e-04 - val_loss: 2.5228e-05 - val_mean_squared_error: 2.5228e-05
# Epoch 208/1000
#  - 17s - loss: 3.1381e-04 - mean_squared_error: 3.1381e-04 - val_loss: 2.5228e-05 - val_mean_squared_error: 2.5228e-05
# Epoch 209/1000
#  - 18s - loss: 3.1429e-04 - mean_squared_error: 3.1429e-04 - val_loss: 2.5340e-05 - val_mean_squared_error: 2.5340e-05
# Epoch 210/1000
#  - 17s - loss: 3.1425e-04 - mean_squared_error: 3.1425e-04 - val_loss: 2.5182e-05 - val_mean_squared_error: 2.5182e-05
# Epoch 211/1000
#  - 18s - loss: 3.1418e-04 - mean_squared_error: 3.1418e-04 - val_loss: 2.6046e-05 - val_mean_squared_error: 2.6046e-05
# Epoch 212/1000
#  - 16s - loss: 3.1431e-04 - mean_squared_error: 3.1431e-04 - val_loss: 2.5288e-05 - val_mean_squared_error: 2.5288e-05
# Epoch 213/1000
#  - 18s - loss: 3.1415e-04 - mean_squared_error: 3.1415e-04 - val_loss: 2.9741e-05 - val_mean_squared_error: 2.9741e-05
# Epoch 214/1000
#  - 17s - loss: 3.1418e-04 - mean_squared_error: 3.1418e-04 - val_loss: 2.5156e-05 - val_mean_squared_error: 2.5156e-05
# Epoch 215/1000

# %%
predict()
