# %%
import matplotlib.pyplot as plt
import numpy

# %%
a = numpy.loadtxt('../data/64-9-3-5.txt')

# %%
plt.figure(figsize=[10,6])
plt.xlabel('Epoch')
plt.ylabel('SSIM')
plt.plot(a)
plt.savefig('9-3-5', bbox_inches='tight')

# %%
b = numpy.loadtxt('../data/64-9-1-5.txt')
plt.figure(figsize=[10,6])
plt.plot(b)
plt.xlabel('Epoch')
plt.ylabel('SSIM')
plt.savefig('9-1-5.png',  bbox_inches='tight')
